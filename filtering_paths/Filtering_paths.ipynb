# %% [markdown]
# # PATHS FILTERING

# %% [markdown]
# <div class="alert alert-success">
# Using our method to find links between artists and POIs we have get a lot of of links,but the majority of them is probably not very interesting.
# The purpose of this Notebook is to discover which are the best links.
# </div>

# %%
import pandas as pd
import csv
import numpy as np
from os import listdir
from os.path import isfile, join
import re
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# <div class="alert alert-success">
# Below we'll save in a pandas dataframe all paths. The dataframe is formed by columns; every columns rapresents a resource(<strong>?o1 ?o2</strong>) or a property(<strong>?p1 ?p2 ?p3</strong>) of the path. They are numerated and  the max depth is 6. The central resource that links POI and enetity is rapresented by the column <strong>?o</strong>.
# </div>

# %%
input_path = 'artists_pois_paths.csv'
df_paths = pd.read_csv(input_path)
print("Total number of paths: ",len(df_paths))
df_paths.head()
# Out:
# Total number of paths:  1536259
#                                             entity  \
# 0  http://dbpedia.org/resource/Theo_Brandmüller
# 1  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 2  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 3  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 4  http://dbpedia.org/resource/Lodewijk_Mortelmans
#
#                                        p1  \
# 0  http://dbpedia.org/ontology/birthPlace
# 1  http://dbpedia.org/ontology/deathPlace
# 2  http://dbpedia.org/ontology/deathPlace
# 3  http://dbpedia.org/ontology/birthPlace
# 4  http://dbpedia.org/ontology/birthPlace
#
#                                     o1                                p2  \
# 0  http://dbpedia.org/resource/Mainz    http://purl.org/dc/terms/subject
# 1  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 2  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 3  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 4  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
#
#                                                                             o2  \
# 0  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Germany
# 1  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Belgium
# 2  http://dbpedia.org/resource/Category:Port_cities_and_towns_of_the_North_Sea
# 3  http://dbpedia.org/resource/Category:Port_cities_and_towns_of_the_North_Sea
# 4  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Belgium
#
#                                             p3  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                             o  \
# 0  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 1  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 2  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 3  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 4  http://dbpedia.org/resource/Category:Port_cities_in_Europe
#
#                                            p3_  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                     o2_  \
# 0  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 1  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 2  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 3  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 4  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
#
#                                            p2_  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                   o1_  \
# 0  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 1  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 2  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 3  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 4  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
#
#                                 p1_  \
# 0  http://purl.org/dc/terms/subject
# 1  http://purl.org/dc/terms/subject
# 2  http://purl.org/dc/terms/subject
# 3  http://purl.org/dc/terms/subject
# 4  http://purl.org/dc/terms/subject
#
#                                                 poi
# 0  http://dbpedia.org/resource/Villefranche-sur-Mer
# 1  http://dbpedia.org/resource/Villefranche-sur-Mer
# 2  http://dbpedia.org/resource/Villefranche-sur-Mer
# 3  http://dbpedia.org/resource/Villefranche-sur-Mer
# 4  http://dbpedia.org/resource/Villefranche-sur-Mer

# %% [markdown]
# <div class="alert alert-success">
# As you can see we have a lot of paths(1536259), but looking at the fist ones very general resources are presented in the path. <a>http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France</a> for example.
# </div>

# %% [markdown]
# ### 1 - FIRST FILTERING STEP: REMOVE DOUBLE INFORMATION

# %% [markdown]
# <div class="alert alert-success">
# In first filtering step we want to remove all paths in which a resource is presented two times. In fact it means that there is a shorter path between the POI and the artist, and it is already present in our table.
# Let's suppose to have these 2 paths (the letters rappresent the resources):
# <ul>
#   <li>A->B->C</li>
#   <li>A->B->E->B->C</li>
# </ul>
# We want to preserve only the first one.
# </div>

# %%
def isDuplicate(x,arr_names):
    g = []
    for n in arr_names:
        if x[n] in g and type(x[n]) != float:
            return False
        else:
            g.append(x[n])
    return True

# %%
#df_paths_rm_duplicates = df_paths[df_paths.apply(lambda x: isDuplicate(x,df.columns[2:-2:2]), axis=1)]
print("Total number of paths: ",len(df_paths_rm_duplicates))
df_paths_rm_duplicates.head()
# Out:
# Total number of paths:  1062259
#                                             entity  \
# 0  http://dbpedia.org/resource/Theo_Brandmüller
# 1  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 2  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 3  http://dbpedia.org/resource/Lodewijk_Mortelmans
# 4  http://dbpedia.org/resource/Lodewijk_Mortelmans
#
#                                        p1  \
# 0  http://dbpedia.org/ontology/birthPlace
# 1  http://dbpedia.org/ontology/deathPlace
# 2  http://dbpedia.org/ontology/deathPlace
# 3  http://dbpedia.org/ontology/birthPlace
# 4  http://dbpedia.org/ontology/birthPlace
#
#                                     o1                                p2  \
# 0  http://dbpedia.org/resource/Mainz    http://purl.org/dc/terms/subject
# 1  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 2  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 3  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
# 4  http://dbpedia.org/resource/Antwerp  http://purl.org/dc/terms/subject
#
#                                                                             o2  \
# 0  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Germany
# 1  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Belgium
# 2  http://dbpedia.org/resource/Category:Port_cities_and_towns_of_the_North_Sea
# 3  http://dbpedia.org/resource/Category:Port_cities_and_towns_of_the_North_Sea
# 4  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_Belgium
#
#                                             p3  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                             o  \
# 0  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 1  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 2  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 3  http://dbpedia.org/resource/Category:Port_cities_in_Europe
# 4  http://dbpedia.org/resource/Category:Port_cities_in_Europe
#
#                                            p3_  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                     o2_  \
# 0  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 1  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 2  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 3  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
# 4  http://dbpedia.org/resource/Category:Port_cities_and_towns_in_France
#
#                                            p2_  \
# 0  http://www.w3.org/2004/02/skos/core#broader
# 1  http://www.w3.org/2004/02/skos/core#broader
# 2  http://www.w3.org/2004/02/skos/core#broader
# 3  http://www.w3.org/2004/02/skos/core#broader
# 4  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                   o1_  \
# 0  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 1  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 2  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 3  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
# 4  http://dbpedia.org/resource/Category:Mediterranean_port_cities_and_towns_in_France
#
#                                 p1_  \
# 0  http://purl.org/dc/terms/subject
# 1  http://purl.org/dc/terms/subject
# 2  http://purl.org/dc/terms/subject
# 3  http://purl.org/dc/terms/subject
# 4  http://purl.org/dc/terms/subject
#
#                                                 poi
# 0  http://dbpedia.org/resource/Villefranche-sur-Mer
# 1  http://dbpedia.org/resource/Villefranche-sur-Mer
# 2  http://dbpedia.org/resource/Villefranche-sur-Mer
# 3  http://dbpedia.org/resource/Villefranche-sur-Mer
# 4  http://dbpedia.org/resource/Villefranche-sur-Mer

# %% [markdown]
# <div class="alert alert-success">
# As you can see we have filtered out 500000 paths.
# </div>

# %%
df_paths_rm_duplicates.to_csv("artists_pois_paths_rm_dubplicates.csv",index=False)

# %% [markdown]
# ### 2 - SECOND FILTERING STEP: REMOVE NOT INTERESTING RESOURCES AND CATEGORIES

# %% [markdown]
# <div class="alert alert-success">
# Now we want to remove the paths formed by resources that are not interesting because they are too generic. So we'll take the resources that appears too frequently in our paths and we'll delete the paths related to these.
# </div>

# %%
df_paths_rm_duplicates = pd.read_csv("artists_pois_paths_rm_dubplicates.csv")

# %%
columns = df_paths_rm_duplicates.columns
number_of_cols = len(columns)

# %%
frames = [df_paths_rm_duplicates.groupby(col)[col].count().reset_index(name="count").rename(columns={col:'resource','count':'count'}) for col in df_paths_rm_duplicates.columns[2:-2:2]]
all_middle_resources = pd.concat(frames)

# %%
all_middle_resources_grouped = (all_middle_resources
                                        .groupby('resource')["count"]
                                        .sum().reset_index(name="count")
                                        .sort_values('count', ascending=False)
                                       )

# %%
all_middle_resources_grouped.head()
# Out:
#                                                          resource   count
# 8387  http://dbpedia.org/resource/OGC_Nice                         414484
# 8021  http://dbpedia.org/resource/Midfielder                       216189
# 7948  http://dbpedia.org/resource/Mediterranean_Sea                142894
# 5353  http://dbpedia.org/resource/Christian_Estrosi                126276
# 5667  http://dbpedia.org/resource/Defender_(association_football)  90248

# %% [markdown]
# <div class="alert alert-success">
# As you can see looking at the table above there are resources that are resources that are present in over 40000 links. They are for sure ourliers, and we want to delete the associated links because, as you can see, they are too generic resorurces.
# To understand which the distribution of our resources we'll show a plot.
# </div>

# %%
plt.figure(figsize=(20,10))
sns.distplot(all_middle_resources_grouped['count'])
sns.plt.show()

# %% [markdown]
# <div class="alert alert-success">
# The majority of our resources seems to be present around 1000-2000 times in our paths. Having some outliners, the zone around 1000-2000 is note really visible in the graph below; so we'll plot only this zone below.
# </div>

# %%
plt.figure(figsize=(20,10))
sns.distplot(all_middle_resources_grouped['count']).set(xlim=(0, 5000))
sns.plt.show()

# %% [markdown]
# <div class="alert alert-success">
# Looking this plot we can note that the most of the resources is present around 1800 times in our paths. We started using this value as threshold to filter out all too generic resources that rapresent noise. Howerver this threshold was too high and some noise remained in our data, so we have set 500 as threshold.
# </div>

# %%
bad_resources = list(all_middle_resources_grouped[all_middle_resources_grouped['count']>1000]['resource'])

# %%
def isBad(x,arr_names,bad_resources):
    for n in arr_names:
        if x[n] in bad_resources:
            return False
    return True

# %%
df_paths_rm_outliers= df_paths_rm_duplicates[df_paths_rm_duplicates.apply(lambda x: isBad(x,columns[2:-2:2],bad_resources), axis=1)]

# %%
print("Total number of paths: ",len(df_paths_rm_outliers))
# Out:
# Total number of paths:  14506

# %% [markdown]
# <div class="alert alert-success">
# As you can see, we have drastically reduced the total number of paths.
# </div>

# %%
df_paths_rm_outliers.to_csv("artists_pois_paths_rm_outliers.csv",index=False)

# %% [markdown]
# ### 3 - THIRD FILTERING STEP: PRESERVE ONLY SHORTEST PATHS

# %% [markdown]
# <div class="alert alert-success">
# Here we want to save only the shortest path between an artist and a POI. A shorter path doesn't mean certainly a better one. However the majority of our paths is really long (6 of depth), so this step is useful to delete all informations repeated.
# Let's suppose to have these 2 paths (the letters rappresent the resources):
# <ul>
#   <li>A->B->D->E->F</li>
#   <li>A->B->C->D->E->F</li>
# </ul>
# We want to preserve only the first one.
# </div>

# %%
df_paths_rm_outliers = pd.read_csv("artists_pois_paths_rm_outliers.csv")
columns = df_paths_rm_outliers.columns

# %%
paths_np = df_paths_rm_outliers.as_matrix()

# %%
filtered_np_as_dict = {}
for count,line in enumerate(paths_np):
    entity = line[0]
    poi = line[-1]
    key=entity+poi
    #print(count)
    if not key in filtered_np_as_dict:
        #print(1)
        filtered_np_as_dict[key] = [line]
    else:
        #print(2)
        oldlines=filtered_np_as_dict[key]
        #print(oldlines)
        for i,ol in enumerate(oldlines):
            #print (ol)
            len1 = len([value for value in ol if type(value)!=float])
            len2 = len([value for value in line if type(value)!=float])
            if len1 > len2:
                #print('a')
                filtered_np_as_dict[key][i] = line
            elif len1 == len2:
                #print('b')
                filtered_np_as_dict[key] = oldlines +[line]

# %%
values_filtered_np_as_dict=filtered_np_as_dict.values()
paths_filtered = pd.DataFrame(np.array([j for i in values_filtered_np_as_dict for j in i]),columns=columns)

# %%
paths_filtered
# Out:
#                                                              entity  \
# 0      http://dbpedia.org/resource/Hamish_MacCunn
# 1      http://dbpedia.org/resource/Hamish_MacCunn
# 2      http://dbpedia.org/resource/Charlélie_Couture
# 3      http://dbpedia.org/resource/Charlélie_Couture
# 4      http://dbpedia.org/resource/Wilhelm_Dieter_Siebert
# 5      http://dbpedia.org/resource/Gordon_Getty
# 6      http://dbpedia.org/resource/Gordon_Getty
# 7      http://dbpedia.org/resource/Jan_Müller-Wieland
# 8      http://dbpedia.org/resource/Jan_Müller-Wieland
# 9      http://dbpedia.org/resource/Jan_Müller-Wieland
# 10     http://dbpedia.org/resource/Jan_Müller-Wieland
# 11     http://dbpedia.org/resource/Gregory_Vajda
# 12     http://dbpedia.org/resource/Hans_Haug
# 13     http://dbpedia.org/resource/Maude_Valerie_White
# 14     http://dbpedia.org/resource/Valentyn_Sylvestrov
# 15     http://dbpedia.org/resource/Albert_Cahen
# 16     http://dbpedia.org/resource/Albert_Cahen
# 17     http://dbpedia.org/resource/Rodion_Shchedrin
# 18     http://dbpedia.org/resource/Rodion_Shchedrin
# 19     http://dbpedia.org/resource/Ignaz_Friedman
# 20     http://dbpedia.org/resource/Ignaz_Friedman
# 21     http://dbpedia.org/resource/Samuel_Pepys
# 22     http://dbpedia.org/resource/Samuel_Pepys
# 23     http://dbpedia.org/resource/Samuel_Pepys
# 24     http://dbpedia.org/resource/Hortense_de_Beauharnais
# 25     http://dbpedia.org/resource/Hortense_de_Beauharnais
# 26     http://dbpedia.org/resource/Hortense_de_Beauharnais
# 27     http://dbpedia.org/resource/Hortense_de_Beauharnais
# 28     http://dbpedia.org/resource/Boris_Pasternak
# 29     http://dbpedia.org/resource/Boris_Pasternak
# ...                                            ...
# 11158  http://dbpedia.org/resource/Alain_Bashung
# 11159  http://dbpedia.org/resource/Sophie_Gail
# 11160  http://dbpedia.org/resource/Francesco_Tristano_Schlimé
# 11161  http://dbpedia.org/resource/Francesco_Tristano_Schlimé
# 11162  http://dbpedia.org/resource/Francesco_Tristano_Schlimé
# 11163  http://dbpedia.org/resource/Francesco_Tristano_Schlimé
# 11164  http://dbpedia.org/resource/Augusta_Read_Thomas
# 11165  http://dbpedia.org/resource/Joseph_Kosma
# 11166  http://dbpedia.org/resource/Joseph_Kosma
# 11167  http://dbpedia.org/resource/Joseph_Kosma
# 11168  http://dbpedia.org/resource/Joseph_Kosma
# 11169  http://dbpedia.org/resource/Richard_Genée
# 11170  http://dbpedia.org/resource/Carl_Friedrich_Zelter
# 11171  http://dbpedia.org/resource/Nolwenn_Leroy
# 11172  http://dbpedia.org/resource/Peter_Hurford
# 11173  http://dbpedia.org/resource/Guillaume_Lekeu
# 11174  http://dbpedia.org/resource/Wilhelm_Killmayer
# 11175  http://dbpedia.org/resource/Wilhelm_Killmayer
# 11176  http://dbpedia.org/resource/Luigi_Cherubini
# 11177  http://dbpedia.org/resource/Guy_Ropartz
# 11178  http://dbpedia.org/resource/Jimmy_Van_Heusen
# 11179  http://dbpedia.org/resource/Friedrich_Nietzsche
# 11180  http://dbpedia.org/resource/Louis_XIII_of_France
# 11181  http://dbpedia.org/resource/Alexandre_Rabinovitch-Barakovsky
# 11182  http://dbpedia.org/resource/Carl_Filtsch
# 11183  http://dbpedia.org/resource/Carl_Filtsch
# 11184  http://dbpedia.org/resource/Carl_Filtsch
# 11185  http://dbpedia.org/resource/Alexandre_Rabinovitch-Barakovsky
# 11186  http://dbpedia.org/resource/Johann_Adam_Hiller
# 11187  http://dbpedia.org/resource/Johann_Adam_Hiller
#
#                                              p1  \
# 0      http://dbpedia.org/ontology/genre
# 1      http://dbpedia.org/property/genre
# 2      http://purl.org/dc/terms/subject
# 3      http://purl.org/dc/terms/subject
# 4      http://purl.org/dc/terms/subject
# 5      http://dbpedia.org/ontology/parent
# 6      http://dbpedia.org/property/parents
# 7      http://dbpedia.org/ontology/education
# 8      http://dbpedia.org/property/education
# 9      http://dbpedia.org/ontology/education
# 10     http://dbpedia.org/property/education
# 11     http://dbpedia.org/ontology/birthPlace
# 12     http://dbpedia.org/ontology/birthPlace
# 13     http://dbpedia.org/ontology/birthPlace
# 14     http://purl.org/dc/terms/subject
# 15     http://dbpedia.org/property/placeOfDeath
# 16     http://dbpedia.org/ontology/deathPlace
# 17     http://purl.org/dc/terms/subject
# 18     http://purl.org/dc/terms/subject
# 19     http://dbpedia.org/ontology/deathPlace
# 20     http://dbpedia.org/property/deathPlace
# 21     http://dbpedia.org/ontology/occupation
# 22     http://dbpedia.org/ontology/party
# 23     http://dbpedia.org/property/party
# 24     http://dbpedia.org/ontology/parent
# 25     http://dbpedia.org/ontology/parent
# 26     http://dbpedia.org/property/mother
# 27     http://dbpedia.org/property/mother
# 28     http://purl.org/dc/terms/subject
# 29     http://purl.org/dc/terms/subject
# ...                                 ...
# 11158  http://dbpedia.org/ontology/genre
# 11159  http://purl.org/dc/terms/subject
# 11160  http://dbpedia.org/ontology/hometown
# 11161  http://dbpedia.org/ontology/hometown
# 11162  http://dbpedia.org/property/origin
# 11163  http://dbpedia.org/property/origin
# 11164  http://purl.org/dc/terms/subject
# 11165  http://dbpedia.org/ontology/hometown
# 11166  http://dbpedia.org/ontology/hometown
# 11167  http://dbpedia.org/property/origin
# 11168  http://dbpedia.org/property/origin
# 11169  http://purl.org/dc/terms/subject
# 11170  http://purl.org/dc/terms/subject
# 11171  http://dbpedia.org/ontology/genre
# 11172  http://purl.org/dc/terms/subject
# 11173  http://purl.org/dc/terms/subject
# 11174  http://dbpedia.org/ontology/award
# 11175  http://dbpedia.org/property/awards
# 11176  http://purl.org/dc/terms/subject
# 11177  http://purl.org/dc/terms/subject
# 11178  http://purl.org/dc/terms/subject
# 11179  http://dbpedia.org/ontology/influencedBy
# 11180  http://purl.org/dc/terms/subject
# 11181  http://purl.org/dc/terms/subject
# 11182  http://dbpedia.org/property/placeOfDeath
# 11183  http://dbpedia.org/ontology/deathPlace
# 11184  http://dbpedia.org/property/deathPlace
# 11185  http://purl.org/dc/terms/subject
# 11186  http://purl.org/dc/terms/subject
# 11187  http://purl.org/dc/terms/subject
#
#                                                                                          o1  \
# 0      http://dbpedia.org/resource/Classical_music
# 1      http://dbpedia.org/resource/Classical_music
# 2      http://dbpedia.org/resource/Category:French_photographers
# 3      http://dbpedia.org/resource/Category:French_poster_artists
# 4      http://dbpedia.org/resource/Category:German_opera_composers
# 5      http://dbpedia.org/resource/J._Paul_Getty
# 6      http://dbpedia.org/resource/J._Paul_Getty
# 7      http://dbpedia.org/resource/Lübeck_Academy_of_Music
# 8      http://dbpedia.org/resource/Lübeck_Academy_of_Music
# 9      http://dbpedia.org/resource/Lübeck_Academy_of_Music
# 10     http://dbpedia.org/resource/Lübeck_Academy_of_Music
# 11     http://dbpedia.org/resource/Budapest
# 12     http://dbpedia.org/resource/Basel
# 13     http://dbpedia.org/resource/Normandy
# 14     http://dbpedia.org/resource/Category:Ukrainian_music
# 15     http://dbpedia.org/resource/La_Turbie
# 16     http://dbpedia.org/resource/La_Turbie
# 17     http://dbpedia.org/resource/Category:People's_Artists_of_the_RSFSR
# 18     http://dbpedia.org/resource/Category:State_Prize_of_the_Russian_Federation_laureates
# 19     http://dbpedia.org/resource/Sydney
# 20     http://dbpedia.org/resource/Sydney
# 21     http://dbpedia.org/resource/Tory
# 22     http://dbpedia.org/resource/Tory
# 23     http://dbpedia.org/resource/Tory
# 24     http://dbpedia.org/resource/Joséphine_de_Beauharnais
# 25     http://dbpedia.org/resource/Joséphine_de_Beauharnais
# 26     http://dbpedia.org/resource/Joséphine_de_Beauharnais
# 27     http://dbpedia.org/resource/Joséphine_de_Beauharnais
# 28     http://dbpedia.org/resource/Category:Russian_Nobel_laureates
# 29     http://dbpedia.org/resource/Category:Russian_Nobel_laureates
# ...                                                             ...
# 11158  http://dbpedia.org/resource/Rock_music
# 11159  http://dbpedia.org/resource/Category:Burials_at_Père_Lachaise_Cemetery
# 11160  http://dbpedia.org/resource/Luxembourg
# 11161  http://dbpedia.org/resource/Luxembourg
# 11162  http://dbpedia.org/resource/Luxembourg
# 11163  http://dbpedia.org/resource/Luxembourg
# 11164  http://dbpedia.org/resource/Category:Charles_Ives_Prize
# 11165  http://dbpedia.org/resource/Budapest
# 11166  http://dbpedia.org/resource/Budapest
# 11167  http://dbpedia.org/resource/Budapest
# 11168  http://dbpedia.org/resource/Budapest
# 11169  http://dbpedia.org/resource/Category:19th-century_dramatists_and_playwrights
# 11170  http://dbpedia.org/resource/Category:Johann_Wolfgang_von_Goethe
# 11171  http://dbpedia.org/resource/Celtic_music
# 11172  http://dbpedia.org/resource/Category:Cathedral_organists
# 11173  http://dbpedia.org/resource/Category:Walloon_people
# 11174  http://dbpedia.org/resource/Bayerische_Akademie_der_Schönen_Künste
# 11175  http://dbpedia.org/resource/Bayerische_Akademie_der_Schönen_Künste
# 11176  http://dbpedia.org/resource/Category:Burials_at_Père_Lachaise_Cemetery
# 11177  http://dbpedia.org/resource/Category:Members_of_the_Académie_des_beaux-arts
# 11178  http://dbpedia.org/resource/Category:Frank_Sinatra
# 11179  http://dbpedia.org/resource/Fyodor_Dostoyevsky
# 11180  http://dbpedia.org/resource/Category:Navarrese_monarchs
# 11181  http://dbpedia.org/resource/Category:Russian_Jews
# 11182  http://dbpedia.org/resource/Venice
# 11183  http://dbpedia.org/resource/Venice
# 11184  http://dbpedia.org/resource/Venice
# 11185  http://dbpedia.org/resource/Category:Swiss_people_of_Russian_descent
# 11186  http://dbpedia.org/resource/Category:Seyler_theatrical_company
# 11187  http://dbpedia.org/resource/Category:Seyler_theatrical_company
#
#                                                  p2  \
# 0      http://purl.org/dc/terms/subject
# 1      http://purl.org/dc/terms/subject
# 2      http://www.w3.org/2004/02/skos/core#broader
# 3      http://www.w3.org/2004/02/skos/core#broader
# 4      http://www.w3.org/2004/02/skos/core#broader
# 5      http://purl.org/dc/terms/subject
# 6      http://purl.org/dc/terms/subject
# 7      http://purl.org/dc/terms/subject
# 8      http://purl.org/dc/terms/subject
# 9      http://purl.org/dc/terms/subject
# 10     http://purl.org/dc/terms/subject
# 11     http://purl.org/dc/terms/subject
# 12     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 13     http://purl.org/dc/terms/subject
# 14     http://www.w3.org/2004/02/skos/core#broader
# 15     http://dbpedia.org/ontology/canton
# 16     http://dbpedia.org/ontology/canton
# 17     http://www.w3.org/2004/02/skos/core#broader
# 18     http://www.w3.org/2004/02/skos/core#broader
# 19     http://purl.org/dc/terms/subject
# 20     http://purl.org/dc/terms/subject
# 21     http://purl.org/dc/terms/subject
# 22     http://purl.org/dc/terms/subject
# 23     http://purl.org/dc/terms/subject
# 24     http://dbpedia.org/ontology/birthPlace
# 25     http://dbpedia.org/property/birthPlace
# 26     http://dbpedia.org/property/birthPlace
# 27     http://dbpedia.org/ontology/birthPlace
# 28     http://www.w3.org/2004/02/skos/core#broader
# 29     http://www.w3.org/2004/02/skos/core#broader
# ...                                            ...
# 11158  http://www.w3.org/2000/01/rdf-schema#seeAlso
# 11159  http://www.w3.org/2004/02/skos/core#broader
# 11160  http://dbpedia.org/ontology/language
# 11161  http://dbpedia.org/ontology/officialLanguage
# 11162  http://dbpedia.org/ontology/language
# 11163  http://dbpedia.org/ontology/officialLanguage
# 11164  http://www.w3.org/2004/02/skos/core#broader
# 11165  http://purl.org/dc/terms/subject
# 11166  http://purl.org/dc/terms/subject
# 11167  http://purl.org/dc/terms/subject
# 11168  http://purl.org/dc/terms/subject
# 11169  http://www.w3.org/2004/02/skos/core#broader
# 11170  http://www.w3.org/2004/02/skos/core#broader
# 11171  http://purl.org/dc/terms/subject
# 11172  http://www.w3.org/2004/02/skos/core#broader
# 11173  http://www.w3.org/2004/02/skos/core#broader
# 11174  http://purl.org/dc/terms/subject
# 11175  http://purl.org/dc/terms/subject
# 11176  http://www.w3.org/2004/02/skos/core#broader
# 11177  http://www.w3.org/2004/02/skos/core#broader
# 11178  http://www.w3.org/2004/02/skos/core#broader
# 11179  http://purl.org/dc/terms/subject
# 11180  http://www.w3.org/2004/02/skos/core#broader
# 11181  http://www.w3.org/2004/02/skos/core#broader
# 11182  http://www.w3.org/2000/01/rdf-schema#seeAlso
# 11183  http://www.w3.org/2000/01/rdf-schema#seeAlso
# 11184  http://www.w3.org/2000/01/rdf-schema#seeAlso
# 11185  http://www.w3.org/2004/02/skos/core#broader
# 11186  http://www.w3.org/2004/02/skos/core#broader
# 11187  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                              o2  \
# 0      http://dbpedia.org/resource/Category:Music_history
# 1      http://dbpedia.org/resource/Category:Music_history
# 2      http://dbpedia.org/resource/Category:French_artists
# 3      http://dbpedia.org/resource/Category:French_artists
# 4      http://dbpedia.org/resource/Category:Opera_in_Germany
# 5      http://dbpedia.org/resource/Category:Museum_founders
# 6      http://dbpedia.org/resource/Category:Museum_founders
# 7      http://dbpedia.org/resource/Category:Music_schools_in_Germany
# 8      http://dbpedia.org/resource/Category:Music_schools_in_Germany
# 9      http://dbpedia.org/resource/Category:Music_schools_in_Germany
# 10     http://dbpedia.org/resource/Category:Music_schools_in_Germany
# 11     http://dbpedia.org/resource/Category:Budapest_metropolitan_area
# 12     http://dbpedia.org/resource/Timeline_of_Basel
# 13     http://dbpedia.org/resource/Category:Former_provinces_of_France
# 14     http://dbpedia.org/resource/Category:Music_by_ethnicity
# 15     http://dbpedia.org/resource/Beausoleil,_Alpes-Maritimes
# 16     http://dbpedia.org/resource/Beausoleil,_Alpes-Maritimes
# 17     http://dbpedia.org/resource/Category:Russian_Soviet_Federative_Socialist_Republic_people
# 18     http://dbpedia.org/resource/Category:Recipients_of_Russian_civil_awards_and_decorations
# 19     http://dbpedia.org/resource/Category:Metropolitan_areas_of_Australia
# 20     http://dbpedia.org/resource/Category:Metropolitan_areas_of_Australia
# 21     http://dbpedia.org/resource/Category:Political_philosophy
# 22     http://dbpedia.org/resource/Category:Political_philosophy
# 23     http://dbpedia.org/resource/Category:Political_philosophy
# 24     http://dbpedia.org/resource/Martinique
# 25     http://dbpedia.org/resource/Martinique
# 26     http://dbpedia.org/resource/Martinique
# 27     http://dbpedia.org/resource/Martinique
# 28     http://dbpedia.org/resource/Category:Science_and_technology_in_Russia
# 29     http://dbpedia.org/resource/Category:Science_and_technology_in_Russia
# ...                                                                      ...
# 11158  http://dbpedia.org/resource/New_Romanticism
# 11159  http://dbpedia.org/resource/Category:Cemeteries_in_Paris
# 11160  http://dbpedia.org/resource/French_language
# 11161  http://dbpedia.org/resource/French_language
# 11162  http://dbpedia.org/resource/French_language
# 11163  http://dbpedia.org/resource/French_language
# 11164  http://dbpedia.org/resource/Category:American_music_awards
# 11165  http://dbpedia.org/resource/Category:Tourism_in_Hungary
# 11166  http://dbpedia.org/resource/Category:Tourism_in_Hungary
# 11167  http://dbpedia.org/resource/Category:Tourism_in_Hungary
# 11168  http://dbpedia.org/resource/Category:Tourism_in_Hungary
# 11169  NaN
# 11170  http://dbpedia.org/resource/Category:19th-century_dramatists_and_playwrights
# 11171  NaN
# 11172  NaN
# 11173  http://dbpedia.org/resource/Category:Francophone_people
# 11174  http://dbpedia.org/resource/Category:Arts_in_Germany
# 11175  http://dbpedia.org/resource/Category:Arts_in_Germany
# 11176  http://dbpedia.org/resource/Category:Cemeteries_in_Paris
# 11177  http://dbpedia.org/resource/Category:Members_of_the_Institut_de_France
# 11178  http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_actors
# 11179  http://dbpedia.org/resource/Category:Eastern_Orthodox_writers
# 11180  http://dbpedia.org/resource/Category:Basque_history
# 11181  http://dbpedia.org/resource/Category:Russian_people_by_religion
# 11182  http://dbpedia.org/resource/Carnival_of_Venice
# 11183  http://dbpedia.org/resource/Carnival_of_Venice
# 11184  http://dbpedia.org/resource/Carnival_of_Venice
# 11185  http://dbpedia.org/resource/Category:People_of_Russian_descent
# 11186  http://dbpedia.org/resource/Category:Theatre_in_Germany
# 11187  http://dbpedia.org/resource/Category:Theatre_in_Germany
#
#                                                 p3  \
# 0      http://www.w3.org/2004/02/skos/core#broader
# 1      http://www.w3.org/2004/02/skos/core#broader
# 2      http://www.w3.org/2004/02/skos/core#broader
# 3      http://www.w3.org/2004/02/skos/core#broader
# 4      http://www.w3.org/2004/02/skos/core#broader
# 5      http://www.w3.org/2004/02/skos/core#broader
# 6      http://www.w3.org/2004/02/skos/core#broader
# 7      http://www.w3.org/2004/02/skos/core#broader
# 8      http://www.w3.org/2004/02/skos/core#broader
# 9      http://www.w3.org/2004/02/skos/core#broader
# 10     http://www.w3.org/2004/02/skos/core#broader
# 11     http://www.w3.org/2004/02/skos/core#broader
# 12     http://purl.org/dc/terms/subject
# 13     http://www.w3.org/2004/02/skos/core#broader
# 14     http://www.w3.org/2004/02/skos/core#broader
# 15     http://purl.org/dc/terms/subject
# 16     http://purl.org/dc/terms/subject
# 17     http://www.w3.org/2004/02/skos/core#broader
# 18     http://www.w3.org/2004/02/skos/core#broader
# 19     http://www.w3.org/2004/02/skos/core#broader
# 20     http://www.w3.org/2004/02/skos/core#broader
# 21     http://www.w3.org/2004/02/skos/core#broader
# 22     http://www.w3.org/2004/02/skos/core#broader
# 23     http://www.w3.org/2004/02/skos/core#broader
# 24     http://purl.org/dc/terms/subject
# 25     http://purl.org/dc/terms/subject
# 26     http://purl.org/dc/terms/subject
# 27     http://purl.org/dc/terms/subject
# 28     http://www.w3.org/2004/02/skos/core#broader
# 29     http://www.w3.org/2004/02/skos/core#broader
# ...                                            ...
# 11158  http://purl.org/dc/terms/subject
# 11159  http://www.w3.org/2004/02/skos/core#broader
# 11160  http://purl.org/dc/terms/subject
# 11161  http://purl.org/dc/terms/subject
# 11162  http://purl.org/dc/terms/subject
# 11163  http://purl.org/dc/terms/subject
# 11164  http://www.w3.org/2004/02/skos/core#broader
# 11165  http://www.w3.org/2004/02/skos/core#broader
# 11166  http://www.w3.org/2004/02/skos/core#broader
# 11167  http://www.w3.org/2004/02/skos/core#broader
# 11168  http://www.w3.org/2004/02/skos/core#broader
# 11169  NaN
# 11170  http://www.w3.org/2004/02/skos/core#broader
# 11171  NaN
# 11172  NaN
# 11173  http://www.w3.org/2004/02/skos/core#broader
# 11174  http://www.w3.org/2004/02/skos/core#broader
# 11175  http://www.w3.org/2004/02/skos/core#broader
# 11176  http://www.w3.org/2004/02/skos/core#broader
# 11177  http://www.w3.org/2004/02/skos/core#broader
# 11178  http://www.w3.org/2004/02/skos/core#broader
# 11179  http://www.w3.org/2004/02/skos/core#broader
# 11180  http://www.w3.org/2004/02/skos/core#broader
# 11181  http://www.w3.org/2004/02/skos/core#broader
# 11182  http://purl.org/dc/terms/subject
# 11183  http://purl.org/dc/terms/subject
# 11184  http://purl.org/dc/terms/subject
# 11185  http://www.w3.org/2004/02/skos/core#broader
# 11186  http://www.w3.org/2004/02/skos/core#broader
# 11187  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                                                       o  \
# 0      http://dbpedia.org/resource/Category:History_by_topic
# 1      http://dbpedia.org/resource/Category:History_by_topic
# 2      http://dbpedia.org/resource/Category:French_art
# 3      http://dbpedia.org/resource/Category:French_art
# 4      http://dbpedia.org/resource/Category:Opera_by_country
# 5      http://dbpedia.org/resource/Category:Biographical_museums
# 6      http://dbpedia.org/resource/Category:Biographical_museums
# 7      http://dbpedia.org/resource/Category:Music_schools_in_Europe
# 8      http://dbpedia.org/resource/Category:Music_schools_in_Europe
# 9      http://dbpedia.org/resource/Category:Music_schools_by_country
# 10     http://dbpedia.org/resource/Category:Music_schools_by_country
# 11     http://dbpedia.org/resource/Category:Metropolitan_areas_of_the_European_Union
# 12     http://dbpedia.org/resource/Category:City_timelines
# 13     http://dbpedia.org/resource/Category:Former_subdivisions_of_France
# 14     http://dbpedia.org/resource/Category:Culture_by_ethnicity
# 15     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 16     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 17     http://dbpedia.org/resource/Category:Russian_people
# 18     http://dbpedia.org/resource/Category:Russian_people
# 19     http://dbpedia.org/resource/Category:Metropolitan_areas_by_country
# 20     http://dbpedia.org/resource/Category:Metropolitan_areas_by_country
# 21     http://dbpedia.org/resource/Category:Subfields_of_political_science
# 22     http://dbpedia.org/resource/Category:Subfields_of_political_science
# 23     http://dbpedia.org/resource/Category:Subfields_of_political_science
# 24     http://dbpedia.org/resource/Category:France_geography_articles_needing_translation_from_French_Wikipedia
# 25     http://dbpedia.org/resource/Category:France_geography_articles_needing_translation_from_French_Wikipedia
# 26     http://dbpedia.org/resource/Category:France_geography_articles_needing_translation_from_French_Wikipedia
# 27     http://dbpedia.org/resource/Category:France_geography_articles_needing_translation_from_French_Wikipedia
# 28     http://dbpedia.org/resource/Category:Science_and_technology_by_country
# 29     http://dbpedia.org/resource/Category:Science_and_technology_in_Europe
# ...                                                                      ...
# 11158  http://dbpedia.org/resource/Category:Neo-romanticism
# 11159  http://dbpedia.org/resource/Category:Cemeteries_in_France
# 11160  http://dbpedia.org/resource/Category:French_language
# 11161  http://dbpedia.org/resource/Category:French_language
# 11162  http://dbpedia.org/resource/Category:French_language
# 11163  http://dbpedia.org/resource/Category:French_language
# 11164  http://dbpedia.org/resource/Category:American_music_industry
# 11165  http://dbpedia.org/resource/Category:Tourism_by_country
# 11166  http://dbpedia.org/resource/Category:Tourism_by_country
# 11167  http://dbpedia.org/resource/Category:Tourism_by_country
# 11168  http://dbpedia.org/resource/Category:Tourism_by_country
# 11169  http://dbpedia.org/resource/Category:19th-century_theatre
# 11170  http://dbpedia.org/resource/Category:19th-century_theatre
# 11171  http://dbpedia.org/resource/Category:Western_European_music
# 11172  http://dbpedia.org/resource/Category:Cathedrals
# 11173  http://dbpedia.org/resource/Category:Francophonie
# 11174  http://dbpedia.org/resource/Category:Arts_by_country
# 11175  http://dbpedia.org/resource/Category:Arts_by_country
# 11176  http://dbpedia.org/resource/Category:Cemeteries_in_France
# 11177  http://dbpedia.org/resource/Category:Institut_de_France
# 11178  http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_people_by_occupation
# 11179  http://dbpedia.org/resource/Category:Eastern_Orthodoxy
# 11180  http://dbpedia.org/resource/Category:History_of_France_by_location
# 11181  http://dbpedia.org/resource/Category:Russian_people
# 11182  http://dbpedia.org/resource/Category:Mardi_Gras
# 11183  http://dbpedia.org/resource/Category:Mardi_Gras
# 11184  http://dbpedia.org/resource/Category:Mardi_Gras
# 11185  http://dbpedia.org/resource/Category:Russian_diaspora
# 11186  http://dbpedia.org/resource/Category:Theatre_by_country
# 11187  http://dbpedia.org/resource/Category:Theatre_by_country
#
#                                                p3_  \
# 0      http://www.w3.org/2004/02/skos/core#broader
# 1      http://www.w3.org/2004/02/skos/core#broader
# 2      NaN
# 3      NaN
# 4      http://www.w3.org/2004/02/skos/core#broader
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     http://www.w3.org/2004/02/skos/core#broader
# 13     http://www.w3.org/2004/02/skos/core#broader
# 14     http://www.w3.org/2004/02/skos/core#broader
# 15     NaN
# 16     NaN
# 17     http://www.w3.org/2004/02/skos/core#broader
# 18     http://www.w3.org/2004/02/skos/core#broader
# 19     NaN
# 20     NaN
# 21     http://www.w3.org/2004/02/skos/core#broader
# 22     http://www.w3.org/2004/02/skos/core#broader
# 23     http://www.w3.org/2004/02/skos/core#broader
# 24     http://www.w3.org/2004/02/skos/core#broader
# 25     http://www.w3.org/2004/02/skos/core#broader
# 26     http://www.w3.org/2004/02/skos/core#broader
# 27     http://www.w3.org/2004/02/skos/core#broader
# 28     http://www.w3.org/2004/02/skos/core#broader
# 29     http://www.w3.org/2004/02/skos/core#broader
# ...                                            ...
# 11158  http://www.w3.org/2004/02/skos/core#broader
# 11159  NaN
# 11160  http://www.w3.org/2004/02/skos/core#broader
# 11161  http://www.w3.org/2004/02/skos/core#broader
# 11162  http://www.w3.org/2004/02/skos/core#broader
# 11163  http://www.w3.org/2004/02/skos/core#broader
# 11164  http://www.w3.org/2004/02/skos/core#broader
# 11165  http://www.w3.org/2004/02/skos/core#broader
# 11166  http://www.w3.org/2004/02/skos/core#broader
# 11167  http://www.w3.org/2004/02/skos/core#broader
# 11168  http://www.w3.org/2004/02/skos/core#broader
# 11169  http://www.w3.org/2004/02/skos/core#broader
# 11170  http://www.w3.org/2004/02/skos/core#broader
# 11171  http://www.w3.org/2004/02/skos/core#broader
# 11172  http://www.w3.org/2004/02/skos/core#broader
# 11173  http://www.w3.org/2004/02/skos/core#broader
# 11174  http://www.w3.org/2004/02/skos/core#broader
# 11175  http://www.w3.org/2004/02/skos/core#broader
# 11176  NaN
# 11177  NaN
# 11178  http://www.w3.org/2004/02/skos/core#broader
# 11179  http://www.w3.org/2004/02/skos/core#broader
# 11180  http://www.w3.org/2004/02/skos/core#broader
# 11181  http://www.w3.org/2004/02/skos/core#broader
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  NaN
# 11186  http://www.w3.org/2004/02/skos/core#broader
# 11187  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                                                              o2_  \
# 0      http://dbpedia.org/resource/Category:History_of_medicine
# 1      http://dbpedia.org/resource/Category:History_of_medicine
# 2      NaN
# 3      NaN
# 4      http://dbpedia.org/resource/Category:Opera_houses_by_country
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     http://dbpedia.org/resource/Category:Timelines_of_cities_in_France
# 13     http://dbpedia.org/resource/Category:Former_cantons_of_France
# 14     http://dbpedia.org/resource/Category:Cemeteries_by_ethnicity
# 15     NaN
# 16     NaN
# 17     http://dbpedia.org/resource/Category:Russian_diaspora
# 18     http://dbpedia.org/resource/Category:Russian_diaspora
# 19     NaN
# 20     NaN
# 21     http://dbpedia.org/resource/Category:International_relations
# 22     http://dbpedia.org/resource/Category:International_relations
# 23     http://dbpedia.org/resource/Category:International_relations
# 24     http://dbpedia.org/resource/Category:Provence-Alpes-Côte_d'Azur_region_articles_needing_translation_from_French_Wikipedia
# 25     http://dbpedia.org/resource/Category:Provence-Alpes-Côte_d'Azur_region_articles_needing_translation_from_French_Wikipedia
# 26     http://dbpedia.org/resource/Category:Provence-Alpes-Côte_d'Azur_region_articles_needing_translation_from_French_Wikipedia
# 27     http://dbpedia.org/resource/Category:Provence-Alpes-Côte_d'Azur_region_articles_needing_translation_from_French_Wikipedia
# 28     http://dbpedia.org/resource/Category:Science_and_technology_in_France
# 29     http://dbpedia.org/resource/Category:Science_and_technology_in_France
# ...                                                                      ...
# 11158  http://dbpedia.org/resource/Category:Gothic_Revival_architecture
# 11159  NaN
# 11160  http://dbpedia.org/resource/Category:French-language_culture
# 11161  http://dbpedia.org/resource/Category:French-language_culture
# 11162  http://dbpedia.org/resource/Category:French-language_culture
# 11163  http://dbpedia.org/resource/Category:French-language_culture
# 11164  http://dbpedia.org/resource/Category:Music_festivals_in_the_United_States
# 11165  http://dbpedia.org/resource/Category:Hotels_by_country
# 11166  http://dbpedia.org/resource/Category:Tourism_in_France
# 11167  http://dbpedia.org/resource/Category:Hotels_by_country
# 11168  http://dbpedia.org/resource/Category:Tourism_in_France
# 11169  http://dbpedia.org/resource/Category:1828_in_theatre
# 11170  http://dbpedia.org/resource/Category:1828_in_theatre
# 11171  http://dbpedia.org/resource/Category:French_music
# 11172  http://dbpedia.org/resource/Category:Cathedrals_by_country
# 11173  http://dbpedia.org/resource/Category:French-language_culture
# 11174  http://dbpedia.org/resource/Category:Art_museums_and_galleries_by_country
# 11175  http://dbpedia.org/resource/Category:Art_museums_and_galleries_by_country
# 11176  NaN
# 11177  NaN
# 11178  http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_artists
# 11179  http://dbpedia.org/resource/Category:Eastern_Orthodoxy_by_country
# 11180  http://dbpedia.org/resource/Category:Histories_of_cities_in_France
# 11181  http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_Russian_people
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  NaN
# 11186  http://dbpedia.org/resource/Category:Theatre_in_France
# 11187  http://dbpedia.org/resource/Category:Theatres_by_country
#
#                                                p2_  \
# 0      http://www.w3.org/2004/02/skos/core#broader
# 1      http://www.w3.org/2004/02/skos/core#broader
# 2      http://www.w3.org/2004/02/skos/core#broader
# 3      http://www.w3.org/2004/02/skos/core#broader
# 4      http://www.w3.org/2004/02/skos/core#broader
# 5      http://www.w3.org/2004/02/skos/core#broader
# 6      http://www.w3.org/2004/02/skos/core#broader
# 7      http://www.w3.org/2004/02/skos/core#broader
# 8      http://www.w3.org/2004/02/skos/core#broader
# 9      http://www.w3.org/2004/02/skos/core#broader
# 10     http://www.w3.org/2004/02/skos/core#broader
# 11     http://www.w3.org/2004/02/skos/core#broader
# 12     http://purl.org/dc/terms/subject
# 13     http://www.w3.org/2004/02/skos/core#broader
# 14     http://www.w3.org/2004/02/skos/core#broader
# 15     NaN
# 16     NaN
# 17     http://www.w3.org/2004/02/skos/core#broader
# 18     http://www.w3.org/2004/02/skos/core#broader
# 19     http://www.w3.org/2004/02/skos/core#broader
# 20     http://www.w3.org/2004/02/skos/core#broader
# 21     http://purl.org/dc/terms/subject
# 22     http://purl.org/dc/terms/subject
# 23     http://purl.org/dc/terms/subject
# 24     http://www.w3.org/2004/02/skos/core#broader
# 25     http://www.w3.org/2004/02/skos/core#broader
# 26     http://www.w3.org/2004/02/skos/core#broader
# 27     http://www.w3.org/2004/02/skos/core#broader
# 28     http://www.w3.org/2004/02/skos/core#broader
# 29     http://www.w3.org/2004/02/skos/core#broader
# ...                                            ...
# 11158  http://www.w3.org/2004/02/skos/core#broader
# 11159  NaN
# 11160  http://www.w3.org/2004/02/skos/core#broader
# 11161  http://www.w3.org/2004/02/skos/core#broader
# 11162  http://www.w3.org/2004/02/skos/core#broader
# 11163  http://www.w3.org/2004/02/skos/core#broader
# 11164  http://www.w3.org/2004/02/skos/core#broader
# 11165  http://www.w3.org/2004/02/skos/core#broader
# 11166  http://www.w3.org/2004/02/skos/core#broader
# 11167  http://www.w3.org/2004/02/skos/core#broader
# 11168  http://www.w3.org/2004/02/skos/core#broader
# 11169  http://www.w3.org/2004/02/skos/core#broader
# 11170  http://www.w3.org/2004/02/skos/core#broader
# ...
# 11177  NaN
# 11178  http://www.w3.org/2004/02/skos/core#broader
# 11179  http://www.w3.org/2004/02/skos/core#broader
# 11180  http://www.w3.org/2004/02/skos/core#broader
# 11181  http://www.w3.org/2004/02/skos/core#broader
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  http://www.w3.org/2004/02/skos/core#broader
# 11186  http://www.w3.org/2004/02/skos/core#broader
# 11187  http://www.w3.org/2004/02/skos/core#broader
#
#                                                                                                                     o1_  \
# 0      http://dbpedia.org/resource/Category:Defunct_hospitals
# 1      http://dbpedia.org/resource/Category:Defunct_hospitals
# 2      http://dbpedia.org/resource/Category:Art_museums_and_galleries_in_France
# 3      http://dbpedia.org/resource/Category:Art_museums_and_galleries_in_France
# 4      http://dbpedia.org/resource/Category:Opera_houses_in_France
# 5      http://dbpedia.org/resource/Category:Museums_devoted_to_one_artist
# 6      http://dbpedia.org/resource/Category:Museums_devoted_to_one_artist
# 7      http://dbpedia.org/resource/Category:Music_schools_in_France
# 8      http://dbpedia.org/resource/Category:Music_schools_in_France
# 9      http://dbpedia.org/resource/Category:Music_schools_in_France
# 10     http://dbpedia.org/resource/Category:Music_schools_in_France
# 11     http://dbpedia.org/resource/Category:Metropolitan_areas_of_France
# 12     http://dbpedia.org/resource/Timeline_of_Nice
# 13     http://dbpedia.org/resource/Category:Former_cantons_of_Alpes-Maritimes
# 14     http://dbpedia.org/resource/Category:Russian_cemeteries
# 15     NaN
# 16     NaN
# 17     http://dbpedia.org/resource/Category:Russian_cemeteries
# 18     http://dbpedia.org/resource/Category:Russian_cemeteries
# 19     http://dbpedia.org/resource/Category:Metropolitan_areas_of_France
# 20     http://dbpedia.org/resource/Category:Metropolitan_areas_of_France
# 21     http://dbpedia.org/resource/Twin_towns_and_sister_cities
# 22     http://dbpedia.org/resource/Twin_towns_and_sister_cities
# 23     http://dbpedia.org/resource/Twin_towns_and_sister_cities
# 24     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 25     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 26     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 27     http://dbpedia.org/resource/Category:Alpes-Maritimes_communes_articles_needing_translation_from_French_Wikipedia
# 28     http://dbpedia.org/resource/Category:Astronomical_observatories_in_France
# 29     http://dbpedia.org/resource/Category:Astronomical_observatories_in_France
# ...                                                                          ...
# 11158  http://dbpedia.org/resource/Category:Gothic_Revival_churches
# 11159  NaN
# 11160  http://dbpedia.org/resource/Category:French_culture
# 11161  http://dbpedia.org/resource/Category:French_culture
# 11162  http://dbpedia.org/resource/Category:French_culture
# 11163  http://dbpedia.org/resource/Category:French_culture
# 11164  http://dbpedia.org/resource/Category:Mardi_Gras
# 11165  http://dbpedia.org/resource/Category:Hotels_in_France
# 11166  http://dbpedia.org/resource/Category:Hotels_in_France
# 11167  http://dbpedia.org/resource/Category:Hotels_in_France
# 11168  http://dbpedia.org/resource/Category:Hotels_in_France
# 11169  http://dbpedia.org/resource/Category:Theatres_completed_in_1828
# 11170  http://dbpedia.org/resource/Category:Theatres_completed_in_1828
# 11171  http://dbpedia.org/resource/Category:Music_schools_in_France
# 11172  http://dbpedia.org/resource/Category:Cathedrals_in_France
# 11173  http://dbpedia.org/resource/Category:French_culture
# 11174  http://dbpedia.org/resource/Category:Art_museums_and_galleries_in_France
# 11175  http://dbpedia.org/resource/Category:Art_museums_and_galleries_in_France
# 11176  NaN
# 11177  NaN
# 11178  http://dbpedia.org/resource/Category:Marc_Chagall
# 11179  http://dbpedia.org/resource/Category:Eastern_Orthodoxy_in_France
# 11180  http://dbpedia.org/resource/Category:History_of_Nice
# 11181  http://dbpedia.org/resource/Category:Marc_Chagall
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  http://dbpedia.org/resource/Category:Russian_cemeteries
# 11186  http://dbpedia.org/resource/Category:Theatres_in_France
# 11187  http://dbpedia.org/resource/Category:Theatres_in_France
#
#                                                 p1_  \
# 0      http://purl.org/dc/terms/subject
# 1      http://purl.org/dc/terms/subject
# 2      http://purl.org/dc/terms/subject
# 3      http://purl.org/dc/terms/subject
# 4      http://purl.org/dc/terms/subject
# 5      http://purl.org/dc/terms/subject
# 6      http://purl.org/dc/terms/subject
# 7      http://purl.org/dc/terms/subject
# 8      http://purl.org/dc/terms/subject
# 9      http://purl.org/dc/terms/subject
# 10     http://purl.org/dc/terms/subject
# 11     http://purl.org/dc/terms/subject
# 12     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 13     http://purl.org/dc/terms/subject
# 14     http://purl.org/dc/terms/subject
# 15     http://purl.org/dc/terms/subject
# 16     http://purl.org/dc/terms/subject
# 17     http://purl.org/dc/terms/subject
# 18     http://purl.org/dc/terms/subject
# 19     http://purl.org/dc/terms/subject
# 20     http://purl.org/dc/terms/subject
# 21     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 22     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 23     http://www.w3.org/2000/01/rdf-schema#seeAlso
# 24     http://purl.org/dc/terms/subject
# 25     http://purl.org/dc/terms/subject
# 26     http://purl.org/dc/terms/subject
# 27     http://purl.org/dc/terms/subject
# 28     http://purl.org/dc/terms/subject
# 29     http://purl.org/dc/terms/subject
# ...                                 ...
# 11158  http://purl.org/dc/terms/subject
# 11159  http://purl.org/dc/terms/subject
# 11160  http://purl.org/dc/terms/subject
# 11161  http://purl.org/dc/terms/subject
# 11162  http://purl.org/dc/terms/subject
# 11163  http://purl.org/dc/terms/subject
# 11164  http://purl.org/dc/terms/subject
# 11165  http://purl.org/dc/terms/subject
# 11166  http://purl.org/dc/terms/subject
# 11167  http://purl.org/dc/terms/subject
# 11168  http://purl.org/dc/terms/subject
# 11169  http://purl.org/dc/terms/subject
# 11170  http://purl.org/dc/terms/subject
# 11171  http://purl.org/dc/terms/subject
# 11172  http://purl.org/dc/terms/subject
# 11173  http://purl.org/dc/terms/subject
# 11174  http://purl.org/dc/terms/subject
# 11175  http://purl.org/dc/terms/subject
# 11176  http://purl.org/dc/terms/subject
# 11177  http://purl.org/dc/terms/subject
# 11178  http://purl.org/dc/terms/subject
# 11179  http://purl.org/dc/terms/subject
# 11180  http://purl.org/dc/terms/subject
# 11181  http://purl.org/dc/terms/subject
# 11182  http://purl.org/dc/terms/subject
# 11183  http://purl.org/dc/terms/subject
# 11184  http://purl.org/dc/terms/subject
# 11185  http://purl.org/dc/terms/subject
# 11186  http://purl.org/dc/terms/subject
# 11187  http://purl.org/dc/terms/subject
#
#                                                                 poi
# 0      http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 1      http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 2      http://dbpedia.org/resource/Château_Grimaldi_(Cagnes)
# 3      http://dbpedia.org/resource/Château_Grimaldi_(Cagnes)
# 4      http://dbpedia.org/resource/Opéra_de_Nice
# 5      http://dbpedia.org/resource/Musée_Matisse_(Nice)
# 6      http://dbpedia.org/resource/Musée_Matisse_(Nice)
# 7      http://dbpedia.org/resource/Conservatory_of_Nice
# 8      http://dbpedia.org/resource/Conservatory_of_Nice
# 9      http://dbpedia.org/resource/Conservatory_of_Nice
# 10     http://dbpedia.org/resource/Conservatory_of_Nice
# 11     http://dbpedia.org/resource/Nice_metropolitan_area
# 12     http://dbpedia.org/resource/Nice
# 13     http://dbpedia.org/resource/Canton_of_Villefranche-sur-Mer
# 14     http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 15     http://dbpedia.org/resource/Beaulieu-sur-Mer
# 16     http://dbpedia.org/resource/Beaulieu-sur-Mer
# 17     http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 18     http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 19     http://dbpedia.org/resource/Nice_metropolitan_area
# 20     http://dbpedia.org/resource/Nice_metropolitan_area
# 21     http://dbpedia.org/resource/Saint-Laurent-du-Var
# 22     http://dbpedia.org/resource/Saint-Laurent-du-Var
# 23     http://dbpedia.org/resource/Saint-Laurent-du-Var
# 24     http://dbpedia.org/resource/Cagnes-sur-Mer
# 25     http://dbpedia.org/resource/Cagnes-sur-Mer
# 26     http://dbpedia.org/resource/Cagnes-sur-Mer
# 27     http://dbpedia.org/resource/Cagnes-sur-Mer
# 28     http://dbpedia.org/resource/Côte_d'Azur_Observatory
# 29     http://dbpedia.org/resource/Côte_d'Azur_Observatory
# ...                                                    ...
# 11158  http://dbpedia.org/resource/Notre-Dame_de_Nice
# 11159  http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 11160  http://dbpedia.org/resource/Nice_Carnival
# 11161  http://dbpedia.org/resource/Nice_Carnival
# 11162  http://dbpedia.org/resource/Nice_Carnival
# 11163  http://dbpedia.org/resource/Nice_Carnival
# 11164  http://dbpedia.org/resource/Nice_Carnival
# 11165  http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 11166  http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 11167  http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 11168  http://dbpedia.org/resource/Grand-Hôtel_du_Cap-Ferrat
# 11169  http://dbpedia.org/resource/Opéra_de_Nice
# 11170  http://dbpedia.org/resource/Opéra_de_Nice
# 11171  http://dbpedia.org/resource/Conservatory_of_Nice
# 11172  http://dbpedia.org/resource/Russian_Orthodox_Cathedral,_Nice
# 11173  http://dbpedia.org/resource/Nice_Carnival
# 11174  http://dbpedia.org/resource/Musée_Marc_Chagall
# 11175  http://dbpedia.org/resource/Musée_Marc_Chagall
# 11176  http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 11177  http://dbpedia.org/resource/Villa_Paradiso
# 11178  http://dbpedia.org/resource/Musée_Marc_Chagall
# 11179  http://dbpedia.org/resource/Russian_Orthodox_Cathedral,_Nice
# 11180  http://dbpedia.org/resource/County_of_Nice
# 11181  http://dbpedia.org/resource/Musée_Marc_Chagall
# 11182  http://dbpedia.org/resource/Nice_Carnival
# 11183  http://dbpedia.org/resource/Nice_Carnival
# 11184  http://dbpedia.org/resource/Nice_Carnival
# 11185  http://dbpedia.org/resource/Russian_Orthodox_Cemetery,_Nice
# 11186  http://dbpedia.org/resource/Théâtre_de_verdure_de_Nice
# 11187  http://dbpedia.org/resource/Théâtre_de_verdure_de_Nice
#
# [11188 rows x 13 columns]

# %%
paths_filtered.to_csv('paths_filtered.csv',index=False)

# %% [markdown]
# <div class="alert alert-success">
# The table above shows a sample of paths that we obtained after 3 filtering steps. There are some bad paths; however some interesting paths start appearing as at line 16.
# </div>

# %%
#NEXT STEPS
#group by POIs to see if which are the POIs with more links and why
#group by artists to see if which are the POIs with more links and why
#order by depth

# %%
#paths_filtered['path_lenght']= paths_filtered.apply(lambda row: len([row[col] for col in columns[2:-2:2] if type(row[col])!=float]),axis=1)
#paths_filtered = paths_filtered.sort_values('path_lenght', ascending=True)
#paths_filtered.head()
