# %%
import csv
import os
from pprint import pprint
import pandas as pd
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
from SPARQLWrapper import SPARQLWrapper,TURTLE,JSON

# %% [markdown]
# # Matching DOREMUS - DBpedia

# %%
POIS_PATH = os.path.normpath('doremus_dbpedia_artists.csv')

with open(POIS_PATH, 'r') as input_fp:

    reader = csv.reader(input_fp, )
    # skip header
    next(reader)
    matches = []
    for row in reader:
        match = dict()
        match['doremus_uri'] = row[0]
        match['dbpedia_uri'] = row[1]
        match['score'] = row[2]
        matches.append(match)

# %%
len(matches)
# Out:
# 6026

# %% [markdown]
# The artists interlinking is evaluated by using as ground truth the one done by [ISNI](http://www.isni.org), for which the mapping is already in the DOREMUS dataset.

# %%
offset = 0
finished = False
ground_truth = []


sparql = SPARQLWrapper("http://data.doremus.org/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery(
"""
select $uri_doremus $dbpedia
where {
$uri_doremus ecrm:P131_is_identified_by $id_doremus.
$uri_doremus a ecrm:E21_Person.
$activity ecrm:P14_carried_out_by $uri_doremus.
$uri_doremus owl:sameAs $dbpedia.
FILTER (strStarts(str($dbpedia), 'http://dbpedia.org/resource/'))
} 
group by $uri_doremus    """ )

results = sparql.query().convert()
if len(results['results']['bindings']) > 0:
    for result in results['results']['bindings']:
        match = dict()
        match['doremus_uri'] = result['uri_doremus']['value']
        match['dbpedia_uri'] = result['dbpedia']['value']
        ground_truth.append(match)

# %%
# compute precision, recall and f-measure for a certain threshold

def stats(all_matches,ground_truth,threshold=0):
    # switch off the results under the treshold
    predicted = []
    for m in all_matches:
        if float(m['score']) >= threshold:
            m['label'] = m['dbpedia_uri']
            predicted.append(m)
        else:
            m['label'] = -1
    
    all_matches_frame = pd.DataFrame(all_matches)
    truth_frame = pd.DataFrame(ground_truth)
    truth_label = list(truth_frame['dbpedia_uri'])
    test_set = pd.merge(all_matches_frame, truth_frame, on='doremus_uri', how='right').sort_values(by='doremus_uri')
    
    predicted_frame = pd.DataFrame(predicted)
    test_predicted = truth_frame.merge(predicted_frame, on='doremus_uri')
    
    # unicode stripping     
    types = test_set.apply(lambda x: pd.lib.infer_dtype(x.values))
    for col in types[types=='unicode'].index:
        test_set[col] = test_set[col].apply(lambda x: x.encode('utf-8').strip())
        
    predict_label = list(test_set['label'])
    
    correct_matches = test_predicted[test_predicted.apply(lambda x: x['dbpedia_uri_x'] == x['dbpedia_uri_y'], axis=1)]
    wrong_matches = test_predicted[test_predicted.apply(lambda x: x['dbpedia_uri_x'] != x['dbpedia_uri_y'], axis=1)]
    
    TP = len(correct_matches) # true positive
    TPFP = len(test_predicted) # true positive + false positive
    TPFN = len(truth_frame) # true positive + false negative

    precision = TP / TPFP
    recall = TP / TPFN
    f1 = 2 * precision * recall / (precision + recall)
        
    return (precision,recall,f1,len(test_predicted),len(predicted),len(truth_frame),len(correct_matches),len(wrong_matches))

# %%
stats(matches,ground_truth, .7)
# Out:
# (0.986910197869102,
#  0.9073607612650434,
#  0.9454651501895597,
#  3285,
#  5426,
#  3573,
#  3242,
#  43)

# %%
stat_list = []
for threshold in np.arange(0,1.0,0.01):
    values = list(stats(matches,ground_truth,threshold))
    values.append(threshold)
    stat_list.append(values)
stat_list = np.array(stat_list)

# %%
# precision,recall,f1,test_predicted,all_predicted,ground_truth,threshold

# %%
plt.plot(stat_list[:,-1],stat_list[:,5])
plt.plot(stat_list[:,-1],stat_list[:,4])
plt.plot(stat_list[:,-1],stat_list[:,3])
plt.plot(stat_list[:,-1],stat_list[:,6])

plt.grid()
plt.xlabel('threshold')
plt.ylabel('n of elements')
plt.legend(['ground truth','all prediction', 'test prediction','correct test prediction'])
plt.xlim([-0.1,1])
plt.savefig('count_artists_dbpedia.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(stat_list[:,-1],stat_list[:,0])
plt.plot(stat_list[:,-1],stat_list[:,1])
plt.plot(stat_list[:,-1],stat_list[:,2])

plt.grid()
plt.xlabel('threshold')
plt.ylabel('score')
plt.legend(['precision','recall','f1'])
plt.savefig('metrics_artists_dbpedia.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# With a Threshold of 0.5 we have:

# %%
threshold = 0.5
I = 0 # index of the selected threshold
for t in stat_list[:,-1]:
    if t == threshold:
        break
    I+=1;

TP = stat_list[:,6][I] # true positive
TPFP = stat_list[:,3][I] # true positive + false positive
TPFN = stat_list[:,5][I] # true positive + false negative

prec = TP / TPFP
rec = TP / TPFN
fmes = 2 * prec * rec / (prec + rec)

print("PRECISION: ", prec)
print("RECALL: ", rec)
print("F-MEASURE: ", fmes)
# Out:
# PRECISION:  0.986776373788
# RECALL:  0.93982647635
# F-MEASURE:  0.962729357798

# %% [markdown]
# ## artists matched differently, choose the threshold

# %%
THRESHOLD = 0.5
predicted = pd.DataFrame(matches)
predicted = predicted[predicted['score'].astype(float) >= THRESHOLD]
true = pd.DataFrame(ground_truth)
join = true.merge(predicted, on='doremus_uri')
types = join.apply(lambda x: pd.lib.infer_dtype(x.values))
for col in types[types=='unicode'].index:
    join[col] = join[col].apply(lambda x: x.encode('utf-8').strip())
join = join[join.apply(lambda x: x['dbpedia_uri_x'] != x['dbpedia_uri_y'], axis=1)]
print(len(join))

a= join[['dbpedia_uri_y','dbpedia_uri_x','doremus_uri','score']].values.tolist()
#for uri in a:
#    pprint(uri)
a= join[['dbpedia_uri_y','dbpedia_uri_x','doremus_uri','score']]
a = a.rename_axis({"dbpedia_uri_y": "our_match", "dbpedia_uri_x": "your_match"}, axis="columns")
a = a.sort_values('score',ascending=False)
a.to_csv('different_artists_'+ str(THRESHOLD)+'.csv',index=False)
# Out:
# 45

# %% [markdown]
# ## artists that are not linked with dbpedia, choose the threshold

# %%
THRESHOLD = 0.9
predicted = pd.DataFrame(matches)
predicted = predicted[predicted['score'].astype(float) > THRESHOLD]
#predicted = predicted[predicted['score'].astype(float) <= 1.1]
true = pd.DataFrame(ground_truth)

predicted = predicted[~predicted['doremus_uri'].isin(true['doremus_uri'])].sort_values(by='score').values.tolist()
print(len(predicted))
#for uri in predicted:
#        pprint(uri)
# Out:
# 1735

# %% [markdown]
# # Matching DOREMUS - Wikidata

# %%
POIS_PATH = os.path.normpath('doremus_wikidata_artists.csv')

with open(POIS_PATH, 'r') as input_fp:

    reader = csv.reader(input_fp, )
    # skip header
    next(reader)
    matches = []
    for row in reader:
        match = dict()
        match['doremus_uri'] = row[0]
        match['wikidata_uri'] = row[1]
        match['score'] = float(row[5])/3
        matches.append(match)

# %%
len(matches)
# Out:
# 2149

# %%
offset = 0
finished = False
true_matches = []


sparql = SPARQLWrapper("http://data.doremus.org/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery(
"""
select $uri_doremus $wikidata
where {
$uri_doremus ecrm:P131_is_identified_by $id_doremus.
$uri_doremus a ecrm:E21_Person.
$activity ecrm:P14_carried_out_by $uri_doremus.
$uri_doremus owl:sameAs $wikidata.
FILTER (strStarts(str($wikidata), 'http://www.wikidata.org/entity/'))
} 
group by $uri_doremus    """ )

results = sparql.query().convert()
if len(results['results']['bindings']) > 0:
    for result in results['results']['bindings']:
        match = dict()
        match['doremus_uri'] = result['uri_doremus']['value']
        match['wikidata_uri'] = result['wikidata']['value']
        true_matches.append(match)

# %%
len(true_matches)
# Out:
# 3952

# %%
def stats(matches,true_matches,threshold=0):
    predicted = pd.DataFrame(matches)
    predicted = predicted[predicted['score'].astype(float) > threshold]

    true = pd.DataFrame(true_matches)
    join = true.merge(predicted, on='doremus_uri')
    predicted_disjoint = predicted[~predicted['doremus_uri'].isin(true['doremus_uri'])].sort_values(by='score')
    types = join.apply(lambda x: pd.lib.infer_dtype(x.values))
    for col in types[types=='unicode'].index:
        join[col] = join[col].apply(lambda x: x.encode('utf-8').strip())
    true_label = list(join['dbpedia_uri_x'])
    predict_label = list(join['dbpedia_uri_y'])
    # calculate accuracy
    accuracy = metrics.accuracy_score(true_label, predict_label)
#    print('accuracy: %.4f' % metrics.accuracy_score(true_label, predict_label))
    precision = metrics.precision_score(true_label, predict_label,average='macro')
#    print('precision: %.4f' % metrics.precision_score(true_label, predict_label,average='macro'))
    recall = metrics.recall_score(true_label, predict_label,average='macro')
#    print('recall: %.4f' % metrics.recall_score(true_label, predict_label,average='macro'))
    f1 = metrics.f1_score(true_label, predict_label,average='macro')
#    print('f1: %.4f' % metrics.f1_score(true_label, predict_label,average='macro'))

    equal = join[join.apply(lambda x: x['dbpedia_uri_x'] == x['dbpedia_uri_y'], axis=1)]
    unequal = join[join.apply(lambda x: x['dbpedia_uri_x'] != x['dbpedia_uri_y'], axis=1)]
    return (accuracy,precision,recall,f1,len(join),len(predicted),len(true),len(equal),len(unequal),len(predicted_disjoint))

# %%
def stats(matches,true_matches,threshold=0):
    predicted = pd.DataFrame(matches)
    predicted = predicted[predicted['score'].astype(float) > threshold]

    true = pd.DataFrame(true_matches)
    join = true.merge(predicted, on='doremus_uri')
    predicted_disjoint = predicted[~predicted['doremus_uri'].isin(true['doremus_uri'])].sort_values(by='score')
    types = join.apply(lambda x: pd.lib.infer_dtype(x.values))
    
    for col in types[types=='unicode'].index:
        join[col] = join[col].apply(lambda x: x.encode('utf-8').strip())
    true_label = list(join['wikidata_uri_x'])
    predict_label = list(join['wikidata_uri_y'])
    # calculate accuracy
    accuracy = metrics.accuracy_score(true_label, predict_label)
#    print('accuracy: %.4f' % metrics.accuracy_score(true_label, predict_label))
    precision = metrics.precision_score(true_label, predict_label,average='macro')
#    print('precision: %.4f' % metrics.precision_score(true_label, predict_label,average='macro'))
    recall = metrics.recall_score(true_label, predict_label,average='macro')
#    print('recall: %.4f' % metrics.recall_score(true_label, predict_label,average='macro'))
    f1 = metrics.f1_score(true_label, predict_label,average='macro')
#    print('f1: %.4f' % metrics.f1_score(true_label, predict_label,average='macro'))

    equal = join[join.apply(lambda x: x['wikidata_uri_x'] == x['wikidata_uri_y'], axis=1)]
    unequal = join[join.apply(lambda x: x['wikidata_uri_x'] != x['wikidata_uri_y'], axis=1)]
    return (accuracy,precision,recall,f1,len(join),len(predicted),len(true),len(equal),len(unequal),len(predicted_disjoint))

# %%
stat_list = []
for threshold in np.arange(0,1.0,0.01):
    values = list(stats(matches,true_matches,threshold))
    values.append(threshold)
    stat_list.append(values)
stat_list = np.array(stat_list)
# Out:
# /Users/pasquale/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/pasquale/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /Users/pasquale/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/pasquale/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
plt.plot(stat_list[:,-1],stat_list[:,6])
plt.plot(stat_list[:,-1],stat_list[:,5])
plt.plot(stat_list[:,-1],stat_list[:,4])
plt.plot(stat_list[:,-1],stat_list[:,7])

plt.grid()
plt.xlabel('threshold')
plt.ylabel('n of elements')
plt.legend(['truth','prediction', 'doremus_intersection','equal'])
plt.savefig('count_artists_wiki.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15,7))

plt.plot(stat_list[:,-1],stat_list[:,6])
plt.plot(stat_list[:,-1],stat_list[:,5])
plt.plot(stat_list[:,-1],stat_list[:,4])
plt.plot(stat_list[:,-1],stat_list[:,9])

plt.grid()
plt.xlabel('threshold', fontsize=20)
plt.ylabel('n of elements', fontsize=20)
plt.legend(['truth','prediction', 'intersection','disjoint'])
plt.savefig('count_artists_wiki_2.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(stat_list[:,-1],stat_list[:,0])
plt.plot(stat_list[:,-1],stat_list[:,1])
plt.plot(stat_list[:,-1],stat_list[:,2])
plt.plot(stat_list[:,-1],stat_list[:,3])
plt.grid()
plt.xlabel('threshold')
plt.ylabel('score')
plt.legend(['accuracy', 'precision','recall','f1'])
plt.savefig('metrics_artists_wiki.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Artists found that are not in ISNI

# %%
predicted = pd.DataFrame(matches)
predicted = predicted[predicted['score'].astype(float) >= 1.0]
true = pd.DataFrame(true_matches)

predicted = predicted[~predicted['doremus_uri'].isin(true['doremus_uri'])].sort_values(by='score').values.tolist()
print(len(predicted))
for uri in predicted:
        pprint(uri)
# Out:
# 413
# ['http://data.doremus.org/artist/009540ee-244b-3332-9c2f-2d6e09603677',
#  1.0,
#  'http://www.wikidata.org/entity/Q5547245']
# ['http://data.doremus.org/artist/a27fc786-1c36-3a70-8e04-649237ed05b6',
#  1.0,
#  'http://www.wikidata.org/entity/Q1231115']
# ['http://data.doremus.org/artist/a27b1b3b-d37d-3f04-a3a2-a62cccfca190',
#  1.0,
#  'http://www.wikidata.org/entity/Q1687860']
# ['http://data.doremus.org/artist/a0d750ec-1d52-378a-8864-c1e499fa8667',
#  1.0,
#  'http://www.wikidata.org/entity/Q966778']
# ['http://data.doremus.org/artist/a0c496af-0c8d-30ed-9858-3e495b4923ad',
#  1.0,
#  'http://www.wikidata.org/entity/Q710733']
# ['http://data.doremus.org/artist/a06fb3a5-2ee7-39fd-93c8-d3cc757cde77',
#  1.0,
#  'http://www.wikidata.org/entity/Q46096']
# ['http://data.doremus.org/artist/9dd438f3-fdc9-355b-893e-e7bb9ab147d9',
#  1.0,
#  'http://www.wikidata.org/entity/Q1290316']
# ['http://data.doremus.org/artist/9dbaadc5-e795-3306-982c-8b2bd5187340',
#  1.0,
#  'http://www.wikidata.org/entity/Q48173']
# ['http://data.doremus.org/artist/9d4b3bcb-83a4-38e4-b551-6c07a2672946',
#  1.0,
#  'http://www.wikidata.org/entity/Q67366']
# ['http://data.doremus.org/artist/9c9f650f-9d3c-3a36-82d6-29dfff8a688c',
#  1.0,
#  'http://www.wikidata.org/entity/Q21981313']
# ['http://data.doremus.org/artist/9b4902c4-b48a-3b12-9c54-f2854cc7b911',
#  1.0,
#  'http://www.wikidata.org/entity/Q279103']
# ['http://data.doremus.org/artist/9a85620e-b7f9-38ee-8275-34045cc54d9f',
#  1.0,
#  'http://www.wikidata.org/entity/Q131861']
# ['http://data.doremus.org/artist/98baeee2-fc60-35a9-a0b1-39d204a0daa8',
#  1.0,
#  'http://www.wikidata.org/entity/Q1345283']
# ['http://data.doremus.org/artist/968fdef2-f4e3-32e9-9f53-a918cebc281d',
#  1.0,
#  'http://www.wikidata.org/entity/Q104358']
# ['http://data.doremus.org/artist/95e6c486-b4ab-3b1e-9995-c3dac7926af6',
#  1.0,
#  'http://www.wikidata.org/entity/Q351394']
# ['http://data.doremus.org/artist/95ddd5dc-670f-3c3c-8e90-4ad652169725',
#  1.0,
#  'http://www.wikidata.org/entity/Q3361449']
# ['http://data.doremus.org/artist/94b66358-d9fb-3b6e-b99a-bf07325e242d',
#  1.0,
#  'http://www.wikidata.org/entity/Q3089619']
# ['http://data.doremus.org/artist/93375089-8e6f-3f0d-8e62-d962529239fb',
#  1.0,
#  'http://www.wikidata.org/entity/Q2958579']
# ['http://data.doremus.org/artist/917b85fd-d7ba-3c54-a010-31dab58f66da',
#  1.0,
#  'http://www.wikidata.org/entity/Q12281201']
# ['http://data.doremus.org/artist/917b2edb-67ff-35e3-acbf-17d91866f64d',
#  1.0,
#  'http://www.wikidata.org/entity/Q380547']
# ['http://data.doremus.org/artist/91719139-6de1-35a0-a37f-96862a98c152',
#  1.0,
#  'http://www.wikidata.org/entity/Q381436']
# ['http://data.doremus.org/artist/8fa57af9-1975-3238-ae97-0a7a23cdd999',
#  1.0,
#  'http://www.wikidata.org/entity/Q436693']
# ['http://data.doremus.org/artist/a2f61d11-f196-326c-8354-8195cfe6aee7',
#  1.0,
#  'http://www.wikidata.org/entity/Q164004']
# ['http://data.doremus.org/artist/a34c6e76-2dd8-3597-a49d-ecadd2edcde6',
#  1.0,
#  'http://www.wikidata.org/entity/Q3372078']
# ['http://data.doremus.org/artist/a408ec52-0198-3b63-8f2d-9e54dea7688e',
#  1.0,
#  'http://www.wikidata.org/entity/Q692171']
# ['http://data.doremus.org/artist/a41bcefe-26c6-3742-87b5-3c391ac0894a',
#  1.0,
#  'http://www.wikidata.org/entity/Q5772932']
# ['http://data.doremus.org/artist/b7e0ee03-6812-3140-8ee2-bfd90c33f128',
#  1.0,
#  'http://www.wikidata.org/entity/Q128746']
# ['http://data.doremus.org/artist/b6b650d6-d670-3277-94be-b8e0a0e72d20',
#  1.0,
#  'http://www.wikidata.org/entity/Q7344385']
# ['http://data.doremus.org/artist/b698644f-46e6-31bd-9f7c-e190b834039b',
#  1.0,
#  'http://www.wikidata.org/entity/Q157672']
# ['http://data.doremus.org/artist/b67c833c-b43a-372f-8171-3db02e0d73c3',
#  1.0,
#  'http://www.wikidata.org/entity/Q710220']
# ['http://data.doremus.org/artist/b653b726-cbc0-3911-b334-ea34c7c1a6ff',
#  1.0,
#  'http://www.wikidata.org/entity/Q4030']
# ['http://data.doremus.org/artist/b61bd526-4c2b-3a19-8992-0030c310f9db',
#  1.0,
#  'http://www.wikidata.org/entity/Q51859']
# ['http://data.doremus.org/artist/b5ffd1f3-9184-398a-8b04-d69adae6bda2',
#  1.0,
#  'http://www.wikidata.org/entity/Q3132140']
# ['http://data.doremus.org/artist/b566beee-73bf-34d8-9ba3-ec241a76d8ab',
#  1.0,
#  'http://www.wikidata.org/entity/Q1369246']
# ['http://data.doremus.org/artist/b4fc24f2-abc7-3488-8f1a-84f88a300720',
#  1.0,
#  'http://www.wikidata.org/entity/Q1377317']
# ['http://data.doremus.org/artist/b3c486b4-311a-3f12-847c-efd9395dfb4d',
#  1.0,
#  'http://www.wikidata.org/entity/Q305202']
# ['http://data.doremus.org/artist/8f760a28-d0d8-3c9f-bc15-995df141cc30',
#  1.0,
#  'http://www.wikidata.org/entity/Q1396982']
# ['http://data.doremus.org/artist/b0f23c36-4c0d-36d3-9d23-0c6509ad7828',
#  1.0,
#  'http://www.wikidata.org/entity/Q1397939']
# ['http://data.doremus.org/artist/af776427-fa1b-31f6-9b6a-ada0ca6cde0c',
#  1.0,
#  'http://www.wikidata.org/entity/Q460721']
# ['http://data.doremus.org/artist/ae54e66a-b0ac-3785-a7c8-9b0fc15eb612',
#  1.0,
#  'http://www.wikidata.org/entity/Q21849613']
# ['http://data.doremus.org/artist/acba8949-e5cb-32f1-9b65-b436a4b6c468',
#  1.0,
#  'http://www.wikidata.org/entity/Q80135']
# ['http://data.doremus.org/artist/abc49d61-e374-31e7-8576-e5a583f6fdfc',
#  1.0,
#  'http://www.wikidata.org/entity/Q87567']
# ['http://data.doremus.org/artist/aa072176-0463-325c-976c-d29a8b1123a9',
#  1.0,
#  'http://www.wikidata.org/entity/Q3268448']
# ['http://data.doremus.org/artist/a83b7557-2e04-3186-ab93-67a5fd5e9be6',
#  1.0,
#  'http://www.wikidata.org/entity/Q213834']
# ['http://data.doremus.org/artist/a6b96d01-8310-3ca4-bf82-62c694acfcaf',
#  1.0,
#  'http://www.wikidata.org/entity/Q213661']
# ['http://data.doremus.org/artist/a4e7bcb8-be7d-3aa0-b441-99a93eeb063c',
#  1.0,
#  'http://www.wikidata.org/entity/Q310687']
# ['http://data.doremus.org/artist/a4d4cc70-15ca-30eb-ab2f-7d5d3f6df893',
#  1.0,
#  'http://www.wikidata.org/entity/Q1374446']
# ['http://data.doremus.org/artist/a4631fa2-d053-37a9-9a95-e9a88a441798',
#  1.0,
#  'http://www.wikidata.org/entity/Q447433']
# ['http://data.doremus.org/artist/b049ee6d-b73a-355e-9e6f-863ca43297c7',
#  1.0,
#  'http://www.wikidata.org/entity/Q6063016']
# ['http://data.doremus.org/artist/8f41d2fd-af19-3dc1-a79c-0552566fbbf5',
#  1.0,
#  'http://www.wikidata.org/entity/Q1027051']
# ['http://data.doremus.org/artist/8edbd65f-b2c9-3d10-8285-5c73aedc4b89',
#  1.0,
#  'http://www.wikidata.org/entity/Q712094']
# ['http://data.doremus.org/artist/8ed5602d-36d9-3be6-896f-cbbeaacdcea6',
#  1.0,
#  'http://www.wikidata.org/entity/Q2373334']
# ['http://data.doremus.org/artist/853d2ba0-208f-3476-9d22-b08215fb20ef',
#  1.0,
#  'http://www.wikidata.org/entity/Q205990']
# ['http://data.doremus.org/artist/85004eb6-db0f-311e-919a-cb24976c6777',
#  1.0,
#  'http://www.wikidata.org/entity/Q3427030']
# ['http://data.doremus.org/artist/84d5297e-e407-33c4-a7ae-5cdde0d06904',
#  1.0,
#  'http://www.wikidata.org/entity/Q947968']
# ['http://data.doremus.org/artist/84aa757a-bd96-3091-8e00-050b1b0504b6',
#  1.0,
#  'http://www.wikidata.org/entity/Q706508']
# ['http://data.doremus.org/artist/84733220-991d-3354-bd44-893ed2d1d092',
#  1.0,
#  'http://www.wikidata.org/entity/Q2755859']
# ['http://data.doremus.org/artist/84347bdc-613a-3c41-8751-2776c22317cb',
#  1.0,
#  'http://www.wikidata.org/entity/Q1770630']
# ['http://data.doremus.org/artist/83d455be-d4e8-3e49-8703-7bb38167b40c',
#  1.0,
#  'http://www.wikidata.org/entity/Q2172534']
# ['http://data.doremus.org/artist/832bbfad-80d5-33ab-92a4-116aa7e3a16d',
#  1.0,
#  'http://www.wikidata.org/entity/Q5817693']
# ['http://data.doremus.org/artist/8264d444-0e87-366b-9ab1-93176e706951',
#  1.0,
#  'http://www.wikidata.org/entity/Q1208405']
# ['http://data.doremus.org/artist/820e29f2-79be-39db-83f4-501938cc3392',
#  1.0,
#  'http://www.wikidata.org/entity/Q876833']
# ['http://data.doremus.org/artist/854a7fe3-36f7-31e2-93e1-dae0fa116087',
#  1.0,
#  'http://www.wikidata.org/entity/Q293985']
# ['http://data.doremus.org/artist/81a8e33c-e93f-39d7-89a0-3d756c839270',
#  1.0,
#  'http://www.wikidata.org/entity/Q368264']
# ['http://data.doremus.org/artist/814b5297-304f-388f-86b2-ceb0e2a9d6dc',
#  1.0,
#  'http://www.wikidata.org/entity/Q2856669']
# ['http://data.doremus.org/artist/81381688-f7e3-3228-a1a4-803a53a5020d',
#  1.0,
#  'http://www.wikidata.org/entity/Q10357598']
# ['http://data.doremus.org/artist/813555dd-fb0a-3463-ae1e-d4df43d0e183',
#  1.0,
#  'http://www.wikidata.org/entity/Q219551']
# ['http://data.doremus.org/artist/80bc8e96-fdb2-3027-affc-32ae70b052dc',
#  1.0,
#  'http://www.wikidata.org/entity/Q362639']
# ['http://data.doremus.org/artist/7ffee0e7-aea6-332f-83a4-ba6f77585608',
#  1.0,
#  'http://www.wikidata.org/entity/Q3035723']
# ['http://data.doremus.org/artist/7fe80e97-5d7c-3ca5-a072-cabda00efb08',
#  1.0,
#  'http://www.wikidata.org/entity/Q471121']
# ['http://data.doremus.org/artist/7f36b7dc-dbbb-3bc6-91f8-0603b92fae4f',
#  1.0,
#  'http://www.wikidata.org/entity/Q144486']
# ['http://data.doremus.org/artist/7f0e19ad-8195-3bca-93c9-d02d0d86fff6',
#  1.0,
#  'http://www.wikidata.org/entity/Q347078']
# ['http://data.doremus.org/artist/7e4001aa-fe83-3304-ae4b-95e5d89eeb0d',
#  1.0,
#  'http://www.wikidata.org/entity/Q469546']
# ['http://data.doremus.org/artist/7ddbc1e5-bb71-3cb4-8b0b-aea4db740000',
#  1.0,
#  'http://www.wikidata.org/entity/Q93227']
# ['http://data.doremus.org/artist/818bcd85-aa1b-3ce6-ac18-3577b66f2820',
#  1.0,
#  'http://www.wikidata.org/entity/Q192958']
# ['http://data.doremus.org/artist/b81a7d84-aecd-318f-80b7-b3d9225a1f38',
#  1.0,
#  'http://www.wikidata.org/entity/Q3270457']
# ['http://data.doremus.org/artist/85819b79-3bf0-3c45-9de6-743733861be3',
#  1.0,
#  'http://www.wikidata.org/entity/Q158436']
# ['http://data.doremus.org/artist/86c02e2b-f6f0-389c-8b01-17af26875f89',
#  1.0,
#  'http://www.wikidata.org/entity/Q1349020']
# ['http://data.doremus.org/artist/8ea5dbb9-03f1-3bf3-bada-90b85750d1f1',
#  1.0,
#  'http://www.wikidata.org/entity/Q223258']
# ['http://data.doremus.org/artist/8e98772b-2d37-3784-a004-31e8c3f5066f',
#  1.0,
#  'http://www.wikidata.org/entity/Q54885']
# ['http://data.doremus.org/artist/8e24d7c8-f363-3252-a5b6-d8106f88379b',
#  1.0,
#  'http://www.wikidata.org/entity/Q678564']
# ['http://data.doremus.org/artist/8e1d37da-d365-3821-81b0-825e95dfdc03',
#  1.0,
#  'http://www.wikidata.org/entity/Q5369193']
# ['http://data.doremus.org/artist/8da4bb77-3185-35fe-9389-d5d7621041d1',
#  1.0,
#  'http://www.wikidata.org/entity/Q957738']
# ['http://data.doremus.org/artist/8d8f30d1-544f-37cf-97f3-84e38469f272',
#  1.0,
#  'http://www.wikidata.org/entity/Q146256']
# ['http://data.doremus.org/artist/8d82dbed-4a26-37bf-8705-215e839a9a89',
#  1.0,
#  'http://www.wikidata.org/entity/Q3561551']
# ['http://data.doremus.org/artist/8d150f52-9bc0-3470-8476-2a2775028153',
#  1.0,
#  'http://www.wikidata.org/entity/Q427701']
# ['http://data.doremus.org/artist/8ce5e5b9-c717-3738-8e4e-48c1854d7d1f',
#  1.0,
#  'http://www.wikidata.org/entity/Q370928']
# ['http://data.doremus.org/artist/8c023f33-ecb4-3d50-bae4-eaa1fb882d56',
#  1.0,
#  'http://www.wikidata.org/entity/Q316795']
# ['http://data.doremus.org/artist/864b5428-cd34-3491-8434-3fb5e57f1030',
#  1.0,
#  'http://www.wikidata.org/entity/Q55524']
# ['http://data.doremus.org/artist/8bede96f-abd6-36e0-b48b-bf742b9402b6',
#  1.0,
#  'http://www.wikidata.org/entity/Q1381033']
# ['http://data.doremus.org/artist/8b6fd8cb-5887-3084-a685-5523ec0ab479',
#  1.0,
#  'http://www.wikidata.org/entity/Q460963']
# ['http://data.doremus.org/artist/8b14d11a-1616-3429-ab65-32ff6866e797',
#  1.0,
#  'http://www.wikidata.org/entity/Q215828']
# ['http://data.doremus.org/artist/8a5dc26c-64ea-3388-8941-85653d615293',
#  1.0,
#  'http://www.wikidata.org/entity/Q335006']
# ['http://data.doremus.org/artist/8a1cce92-8e27-3f43-bb65-b4e364382539',
#  1.0,
#  'http://www.wikidata.org/entity/Q450797']
# ['http://data.doremus.org/artist/88b67a7d-7dc5-30a0-9e72-603a2cb9662c',
#  1.0,
#  'http://www.wikidata.org/entity/Q926850']
# ['http://data.doremus.org/artist/887dd613-1e60-3f25-9c6e-71a62fadb6e3',
#  1.0,
#  'http://www.wikidata.org/entity/Q882']
# ['http://data.doremus.org/artist/8853bb3c-8815-3d87-82cd-ec167448c296',
#  1.0,
#  'http://www.wikidata.org/entity/Q805870']
# ['http://data.doremus.org/artist/87d7d1f1-ac95-3b5d-b530-1a82a8d7631f',
#  1.0,
#  'http://www.wikidata.org/entity/Q457764']
# ['http://data.doremus.org/artist/87d3908a-30f1-387b-92c7-688f26bd72a4',
#  1.0,
#  'http://www.wikidata.org/entity/Q329443']
# ['http://data.doremus.org/artist/8754b8ce-b3e9-330f-89a6-a2a8e0f5405b',
#  1.0,
#  'http://www.wikidata.org/entity/Q105715']
# ['http://data.doremus.org/artist/8bc329c0-6cbc-3468-bd14-2d5d0967e1fd',
#  1.0,
#  'http://www.wikidata.org/entity/Q7314']
# ['http://data.doremus.org/artist/b89645c1-1396-3e30-88dc-7822c376a189',
#  1.0,
#  'http://www.wikidata.org/entity/Q1060422']
# ['http://data.doremus.org/artist/bbd4ff6f-5d2c-388d-b321-e46c947633a4',
#  1.0,
#  'http://www.wikidata.org/entity/Q89540']
# ['http://data.doremus.org/artist/bbecd5d8-9ca4-36ef-91e0-30b22f1753fe',
#  1.0,
#  'http://www.wikidata.org/entity/Q455515']
# ['http://data.doremus.org/artist/ebdc7171-7247-36a9-94ec-5e3cebc02317',
#  1.0,
#  'http://www.wikidata.org/entity/Q11934957']
# ['http://data.doremus.org/artist/eb3d057d-3581-3a1c-8f22-f65e03e2267a',
#  1.0,
#  'http://www.wikidata.org/entity/Q449299']
# ['http://data.doremus.org/artist/eacecd30-3651-370d-b591-953756fed662',
#  1.0,
#  'http://www.wikidata.org/entity/Q451307']
# ['http://data.doremus.org/artist/ea01b548-2aab-37e5-b0ec-2f10502d6969',
#  1.0,
#  'http://www.wikidata.org/entity/Q2605041']
# ['http://data.doremus.org/artist/e980f337-ad19-3c67-a5b1-6beaee8b3467',
#  1.0,
#  'http://www.wikidata.org/entity/Q442978']
# ['http://data.doremus.org/artist/e883aa9c-15cb-3700-a6e0-732f8278dd79',
#  1.0,
#  'http://www.wikidata.org/entity/Q321630']
# ['http://data.doremus.org/artist/e739aca5-65a0-38f1-aeda-024d4d1d18be',
#  1.0,
#  'http://www.wikidata.org/entity/Q5540016']
# ['http://data.doremus.org/artist/e71f78ca-fc68-334a-a11d-f847def5f74b',
#  1.0,
#  'http://www.wikidata.org/entity/Q934369']
# ['http://data.doremus.org/artist/e71ae9bc-f463-3a87-9255-3b2f117e46fb',
#  1.0,
#  'http://www.wikidata.org/entity/Q351383']
# ['http://data.doremus.org/artist/e6d3b06a-d2e1-39aa-9a58-b7f33a97c46c',
#  1.0,
#  'http://www.wikidata.org/entity/Q439696']
# ['http://data.doremus.org/artist/ee2752a4-8d12-3b2a-bde8-7c51c1e4a35a',
#  1.0,
#  'http://www.wikidata.org/entity/Q947908']
# ['http://data.doremus.org/artist/e60575f0-ba88-3ec4-abe7-663f223cb229',
#  1.0,
#  'http://www.wikidata.org/entity/Q23303956']
# ['http://data.doremus.org/artist/e5eb05c6-e3b3-37e2-bf53-7e68afe6fae2',
#  1.0,
#  'http://www.wikidata.org/entity/Q371862']
# ['http://data.doremus.org/artist/e57f1141-b60b-3387-8f40-d763ac25f7f7',
#  1.0,
#  'http://www.wikidata.org/entity/Q946522']
# ['http://data.doremus.org/artist/e50b316c-bcc7-3535-9398-f64309d89d58',
#  1.0,
#  'http://www.wikidata.org/entity/Q224002']
# ['http://data.doremus.org/artist/e4fc14e7-fe55-32f1-81cf-3c12ceee59e3',
#  1.0,
#  'http://www.wikidata.org/entity/Q12281201']
# ['http://data.doremus.org/artist/e4bbbebb-3a68-3b38-88c1-99ca1a7aa661',
#  1.0,
#  'http://www.wikidata.org/entity/Q605643']
# ['http://data.doremus.org/artist/e4a1ea77-8eeb-3e41-b056-7cbb533445d1',
#  1.0,
#  'http://www.wikidata.org/entity/Q507789']
# ['http://data.doremus.org/artist/e432a18f-591c-3e7e-a1b7-eea8ffac6051',
#  1.0,
#  'http://www.wikidata.org/entity/Q117110']
# ['http://data.doremus.org/artist/e3f7990e-c651-3498-9903-dd798b7a0fca',
#  1.0,
#  'http://www.wikidata.org/entity/Q513203']
# ['http://data.doremus.org/artist/e3d81d31-8142-353f-8492-8cd833b67e3e',
#  1.0,
#  'http://www.wikidata.org/entity/Q1289465']
# ['http://data.doremus.org/artist/e3acd7a0-aeb7-32d5-a0c8-5e4535db51c8',
#  1.0,
#  'http://www.wikidata.org/entity/Q1499487']
# ['http://data.doremus.org/artist/e5f42a6c-2f15-3f4c-8757-055c5933e1cf',
#  1.0,
#  'http://www.wikidata.org/entity/Q706921']
# ['http://data.doremus.org/artist/e3686479-df77-37cb-b766-1a05c1b87fe6',
#  1.0,
#  'http://www.wikidata.org/entity/Q4892960']
# ['http://data.doremus.org/artist/ee7251cd-9982-3600-a94b-d749d9417ff0',
#  1.0,
#  'http://www.wikidata.org/entity/Q2756975']
# ['http://data.doremus.org/artist/ef0fb498-df65-32bf-886b-e537083bf809',
#  1.0,
#  'http://www.wikidata.org/entity/Q450467']
# ['http://data.doremus.org/artist/fdca5ada-c52c-3548-8098-da4ffd497779',
#  1.0,
#  'http://www.wikidata.org/entity/Q6041561']
# ['http://data.doremus.org/artist/fd06885a-227c-307d-a197-99b8e3d8c1be',
#  1.0,
#  'http://www.wikidata.org/entity/Q49481']
# ['http://data.doremus.org/artist/fd01e11b-8b66-3e26-903f-6f20e6de10ae',
#  1.0,
#  'http://www.wikidata.org/entity/Q15869']
# ['http://data.doremus.org/artist/fc1576dd-e30b-378d-9b77-6f3118df437f',
#  1.0,
#  'http://www.wikidata.org/entity/Q22911074']
# ['http://data.doremus.org/artist/fb84355d-48d0-3a29-b9e3-5d258e0b1fb9',
#  1.0,
#  'http://www.wikidata.org/entity/Q787155']
# ['http://data.doremus.org/artist/fb181116-c437-30c3-9eb5-9a055d9819f1',
#  1.0,
#  'http://www.wikidata.org/entity/Q377409']
# ['http://data.doremus.org/artist/f86db654-aab9-37e3-9e0b-6dd508c826f6',
#  1.0,
#  'http://www.wikidata.org/entity/Q932694']
# ['http://data.doremus.org/artist/f85d95d7-485a-3cd7-a13c-0df3739db348',
#  1.0,
#  'http://www.wikidata.org/entity/Q132682']
# ['http://data.doremus.org/artist/f753314d-87a7-32a9-9218-da98ae4f9812',
#  1.0,
#  'http://www.wikidata.org/entity/Q7351']
# ['http://data.doremus.org/artist/f64856a3-f580-3ad1-a98e-f7747d2701e8',
#  1.0,
#  'http://www.wikidata.org/entity/Q506312']
# ['http://data.doremus.org/artist/eeb85f72-2b73-31ec-af0f-b1b2fa5ede08',
#  1.0,
#  'http://www.wikidata.org/entity/Q1079150']
# ['http://data.doremus.org/artist/f5f3717c-6b8f-3536-9616-eacd4e907a4f',
#  1.0,
#  'http://www.wikidata.org/entity/Q926422']
# ['http://data.doremus.org/artist/f5310508-56a6-32f5-a30b-a6a6daf52f6c',
#  1.0,
#  'http://www.wikidata.org/entity/Q965853']
# ['http://data.doremus.org/artist/f4d29759-4670-39d6-af29-950fbddb3a89',
#  1.0,
#  'http://www.wikidata.org/entity/Q1940929']
# ['http://data.doremus.org/artist/f489b746-6c40-301a-baf9-940210be9eb9',
#  1.0,
#  'http://www.wikidata.org/entity/Q1348195']
# ['http://data.doremus.org/artist/f247a862-aec7-3971-865d-49fb88a94fb4',
#  1.0,
#  'http://www.wikidata.org/entity/Q2099524']
# ['http://data.doremus.org/artist/f21d8301-fcf8-31d8-b0fe-dc8960d6e8cb',
#  1.0,
#  'http://www.wikidata.org/entity/Q7184209']
# ['http://data.doremus.org/artist/f21bdcb3-565c-3a69-aa3f-67680a28e824',
#  1.0,
#  'http://www.wikidata.org/entity/Q7302']
# ['http://data.doremus.org/artist/f1ee73f4-0d96-3bdb-b4d3-9eeff25244ee',
#  1.0,
#  'http://www.wikidata.org/entity/Q191499']
# ['http://data.doremus.org/artist/f199de41-f14a-39e1-a730-4ffe1390c616',
#  1.0,
#  'http://www.wikidata.org/entity/Q1454572']
# ['http://data.doremus.org/artist/f0e195c3-408f-31f9-bcab-62288cd8e341',
#  1.0,
#  'http://www.wikidata.org/entity/Q132682']
# ['http://data.doremus.org/artist/ef6262e2-ff06-3755-9ec6-1cde0c7efc5c',
#  1.0,
#  'http://www.wikidata.org/entity/Q1930858']
# ['http://data.doremus.org/artist/f5ef9261-b653-3955-9e94-dbb2447b557d',
#  1.0,
#  'http://www.wikidata.org/entity/Q1391004']
# ['http://data.doremus.org/artist/7dd8439c-df5f-3c37-815d-b3a0939342f1',
#  1.0,
#  'http://www.wikidata.org/entity/Q960070']
# ['http://data.doremus.org/artist/e20f3055-68ec-3f7d-a1e7-8fd0447e2c90',
#  1.0,
#  'http://www.wikidata.org/entity/Q156472']
# ['http://data.doremus.org/artist/de852daa-1017-3380-b902-13d22f687671',
#  1.0,
#  'http://www.wikidata.org/entity/Q509963']
# ['http://data.doremus.org/artist/c8ee53f7-d8d5-3b06-97b1-cbba476fd9d2',
#  1.0,
#  'http://www.wikidata.org/entity/Q2602197']
# ['http://data.doremus.org/artist/c6d3c2ba-42b9-3b51-9339-45cc48b52fc9',
#  1.0,
#  'http://www.wikidata.org/entity/Q119957']
# ['http://data.doremus.org/artist/c68e1f0f-59ab-3876-9cba-bf414d9e39bb',
#  1.0,
#  'http://www.wikidata.org/entity/Q1585912']
# ['http://data.doremus.org/artist/c63382a0-f31d-31cb-921c-42bab6e71c06',
#  1.0,
#  'http://www.wikidata.org/entity/Q367830']
# ['http://data.doremus.org/artist/c5d5735c-1095-3ed4-a20f-1208ab9567f9',
#  1.0,
#  'http://www.wikidata.org/entity/Q9726']
# ['http://data.doremus.org/artist/c58cba33-467a-3861-b533-dba3bd80313b',
#  1.0,
#  'http://www.wikidata.org/entity/Q6745106']
# ['http://data.doremus.org/artist/c581562d-d559-372c-aa03-6eb60bb49786',
#  1.0,
#  'http://www.wikidata.org/entity/Q100471']
# ['http://data.doremus.org/artist/c55510f4-d460-34ab-9650-6ffcbfec324d',
#  1.0,
#  'http://www.wikidata.org/entity/Q784490']
# ['http://data.doremus.org/artist/c4e5a684-b1a2-3208-b400-e5fdd3a83714',
#  1.0,
#  'http://www.wikidata.org/entity/Q1275145']
# ['http://data.doremus.org/artist/c3e81835-a9cb-3e51-a492-410c9e4483aa',
#  1.0,
#  'http://www.wikidata.org/entity/Q322931']
# ['http://data.doremus.org/artist/c8f19185-bba1-376c-a3d9-387e1856304f',
#  1.0,
#  'http://www.wikidata.org/entity/Q236438']
# ['http://data.doremus.org/artist/c22f22a3-8daf-39c4-92b6-1f3618b54722',
#  1.0,
#  'http://www.wikidata.org/entity/Q507947']
# ['http://data.doremus.org/artist/c104c653-ded3-3a1d-b617-92eb947bf475',
#  1.0,
#  'http://www.wikidata.org/entity/Q694123']
# ['http://data.doremus.org/artist/c0da8fc9-6eda-35ea-8748-f9ca14d1b836',
#  1.0,
#  'http://www.wikidata.org/entity/Q152293']
# ['http://data.doremus.org/artist/c0753b55-6bfb-3532-90ce-bf8c21b1eb64',
#  1.0,
#  'http://www.wikidata.org/entity/Q49575']
# ['http://data.doremus.org/artist/bfe16581-4514-3839-b85c-ffaad9fe8f68',
#  1.0,
#  'http://www.wikidata.org/entity/Q1275093']
# ['http://data.doremus.org/artist/bf472326-4102-3de7-a6f4-e015bd647f2f',
#  1.0,
#  'http://www.wikidata.org/entity/Q872568']
# ['http://data.doremus.org/artist/bf02847c-3abb-33ac-86e7-03bba4e39db9',
#  1.0,
#  'http://www.wikidata.org/entity/Q21031823']
# ['http://data.doremus.org/artist/bec8ac0f-f4d3-3af2-9fb0-a5798610eaf7',
#  1.0,
#  'http://www.wikidata.org/entity/Q432573']
# ['http://data.doremus.org/artist/be7238b7-7c8c-3c98-88a1-2c8f1f82344e',
#  1.0,
#  'http://www.wikidata.org/entity/Q5444418']
# ['http://data.doremus.org/artist/bcd36378-9407-3973-b8c8-c9d108732dd2',
#  1.0,
#  'http://www.wikidata.org/entity/Q1785163']
# ['http://data.doremus.org/artist/bc5266d9-ed0b-3abf-9b90-f7c335c17e75',
#  1.0,
#  'http://www.wikidata.org/entity/Q528781']
# ['http://data.doremus.org/artist/c1ac5078-d24e-3297-922d-fe31302360b4',
#  1.0,
#  'http://www.wikidata.org/entity/Q3289100']
# ['http://data.doremus.org/artist/e0e90da9-0969-300c-96aa-eba83f8e64dc',
#  1.0,
#  'http://www.wikidata.org/entity/Q2041861']
# ['http://data.doremus.org/artist/c94c4361-3725-3d9d-ae42-fe64f8d861be',
#  1.0,
#  'http://www.wikidata.org/entity/Q78703']
# ['http://data.doremus.org/artist/ccd9fe59-3f28-3354-9adf-f3e3875d2217',
#  1.0,
#  'http://www.wikidata.org/entity/Q217613']
# ['http://data.doremus.org/artist/dc2afd49-a946-37fd-a9ef-d48728ce464c',
#  1.0,
#  'http://www.wikidata.org/entity/Q2603318']
# ['http://data.doremus.org/artist/db1b2658-8416-3f28-94cb-32e5303b19de',
#  1.0,
#  'http://www.wikidata.org/entity/Q11998270']
# ['http://data.doremus.org/artist/db02fd1a-9e74-3e7e-ae47-525f1f5bdcda',
#  1.0,
#  'http://www.wikidata.org/entity/Q429147']
# ['http://data.doremus.org/artist/daec81ba-a882-3bc1-83c7-b6cee470ffc2',
#  1.0,
#  'http://www.wikidata.org/entity/Q1698']
# ['http://data.doremus.org/artist/dad2f7fd-36c5-346d-9fdd-7f11082e8522',
#  1.0,
#  'http://www.wikidata.org/entity/Q728905']
# ['http://data.doremus.org/artist/d9eb11e0-6163-3209-93b4-4c66b2041d71',
#  1.0,
#  'http://www.wikidata.org/entity/Q2503905']
# ['http://data.doremus.org/artist/d9c5669a-45d1-356a-bb5e-404c4e21bd9b',
#  1.0,
#  'http://www.wikidata.org/entity/Q458775']
# ['http://data.doremus.org/artist/d9120af4-a2da-3d62-be4e-35ab328915d3',
#  1.0,
#  'http://www.wikidata.org/entity/Q1070832']
# ['http://data.doremus.org/artist/d87520ed-bc8c-3a1e-82fd-6c822c0ddab7',
#  1.0,
#  'http://www.wikidata.org/entity/Q1289465']
# ['http://data.doremus.org/artist/d6a3b217-2592-34cf-a383-f9dce81f3898',
#  1.0,
#  'http://www.wikidata.org/entity/Q29577']
# ['http://data.doremus.org/artist/c9baacf1-d4f9-30d0-9290-2af7b44a0f34',
#  1.0,
#  'http://www.wikidata.org/entity/Q481557']
# ['http://data.doremus.org/artist/d5fd7b66-6bb1-3fa5-8abc-2dab1592c19a',
#  1.0,
#  'http://www.wikidata.org/entity/Q1053284']
# ['http://data.doremus.org/artist/d2e26518-a0ce-32b7-ab03-504f56cd9b3a',
#  1.0,
#  'http://www.wikidata.org/entity/Q741034']
# ['http://data.doremus.org/artist/d2a967a5-df08-325f-b316-d67f7a219942',
#  1.0,
#  'http://www.wikidata.org/entity/Q320065']
# ['http://data.doremus.org/artist/cfa5abcb-6402-3d8b-b740-dafd4fd58831',
#  1.0,
#  'http://www.wikidata.org/entity/Q89540']
# ['http://data.doremus.org/artist/ceb89908-183a-39ed-98ec-779601afaa68',
#  1.0,
#  'http://www.wikidata.org/entity/Q1282487']
# ['http://data.doremus.org/artist/ce4dace7-2a50-3ce7-bc79-e8f776512fc3',
#  1.0,
#  'http://www.wikidata.org/entity/Q3934587']
# ['http://data.doremus.org/artist/ce41b86a-08bc-3ddf-8e82-b5ba0a723836',
#  1.0,
#  'http://www.wikidata.org/entity/Q57244']
# ['http://data.doremus.org/artist/cde11cd3-4f5a-3a2c-b031-1c8efaf968c9',
#  1.0,
#  'http://www.wikidata.org/entity/Q1052282']
# ['http://data.doremus.org/artist/cd6e18c7-a0da-3c3d-91ce-ac68eb7a4226',
#  1.0,
#  'http://www.wikidata.org/entity/Q3089649']
# ['http://data.doremus.org/artist/cd678114-3b76-34f4-a57f-c4fadb36b209',
#  1.0,
#  'http://www.wikidata.org/entity/Q2127710']
# ['http://data.doremus.org/artist/ccfbeb99-bfef-393d-ab3a-7c3df29290cf',
#  1.0,
#  'http://www.wikidata.org/entity/Q158078']
# ['http://data.doremus.org/artist/d4c20650-78b0-3c98-8032-5c471f6ffaf3',
#  1.0,
#  'http://www.wikidata.org/entity/Q593611']
# ['http://data.doremus.org/artist/fe3b08b9-966c-38e9-a1bf-0b9abad0ae2f',
#  1.0,
#  'http://www.wikidata.org/entity/Q898138']
# ['http://data.doremus.org/artist/7d667897-d022-3f12-b6d1-642ac1c2de7e',
#  1.0,
#  'http://www.wikidata.org/entity/Q318060']
# ['http://data.doremus.org/artist/7d041d1f-61ee-38ce-b418-5e811e669e37',
#  1.0,
#  'http://www.wikidata.org/entity/Q1298823']
# ['http://data.doremus.org/artist/2d23e500-4150-3065-aa0d-0f9deeb16683',
#  1.0,
#  'http://www.wikidata.org/entity/Q1657552']
# ['http://data.doremus.org/artist/2d1fb5f8-5955-3bc1-b8cb-425dcd150044',
#  1.0,
#  'http://www.wikidata.org/entity/Q208375']
# ['http://data.doremus.org/artist/2c4c5d2c-6a8f-3720-9df3-d3d9040eb323',
#  1.0,
#  'http://www.wikidata.org/entity/Q1282967']
# ['http://data.doremus.org/artist/2b42858a-3421-32e3-a9e4-63ad6ac0804b',
#  1.0,
#  'http://www.wikidata.org/entity/Q1349428']
# ['http://data.doremus.org/artist/2adf206d-9006-3121-9b73-3124b7d7c790',
#  1.0,
#  'http://www.wikidata.org/entity/Q1347620']
# ['http://data.doremus.org/artist/2a72a10b-1603-3c2a-985a-93e2cea55461',
#  1.0,
#  'http://www.wikidata.org/entity/Q215869']
# ['http://data.doremus.org/artist/29ea7fd9-dc6a-3a5f-83e8-cda71c6c2aaa',
#  1.0,
#  'http://www.wikidata.org/entity/Q330230']
# ['http://data.doremus.org/artist/2995cb74-4bbb-3839-bcdc-25e0ee2e82f8',
#  1.0,
#  'http://www.wikidata.org/entity/Q325032']
# ['http://data.doremus.org/artist/290ac4ca-21a4-3353-b8fa-02be1fdbf311',
#  1.0,
#  'http://www.wikidata.org/entity/Q3771066']
# ['http://data.doremus.org/artist/28f637c2-81e1-3ab4-8c23-b18d12eedd18',
#  1.0,
#  'http://www.wikidata.org/entity/Q453460']
# ['http://data.doremus.org/artist/25973374-a895-3966-9445-8f695ef5a5f0',
#  1.0,
#  'http://www.wikidata.org/entity/Q153637']
# ['http://data.doremus.org/artist/253be595-b5d6-32ed-bcaa-e0851f3143ff',
#  1.0,
#  'http://www.wikidata.org/entity/Q1237139']
# ['http://data.doremus.org/artist/2457502b-05a6-3302-b81e-752c92816032',
#  1.0,
#  'http://www.wikidata.org/entity/Q208338']
# ['http://data.doremus.org/artist/237b8a9c-77f0-325e-918d-d7ba8af4d066',
#  1.0,
#  'http://www.wikidata.org/entity/Q1980821']
# ['http://data.doremus.org/artist/2377df7b-b2d2-3543-9e0f-e0e1564e6ebc',
#  1.0,
#  'http://www.wikidata.org/entity/Q1780895']
# ['http://data.doremus.org/artist/22a8da9c-5c39-3754-a3bd-0e64dbfcd5e1',
#  1.0,
#  'http://www.wikidata.org/entity/Q179277']
# ['http://data.doremus.org/artist/22676a30-29ac-322b-a75e-882df38eb145',
#  1.0,
#  'http://www.wikidata.org/entity/Q48363']
# ['http://data.doremus.org/artist/22380fae-1104-30eb-8204-d342927733b3',
#  1.0,
#  'http://www.wikidata.org/entity/Q298388']
# ['http://data.doremus.org/artist/21d53692-da6b-3742-8aad-c1741352c58e',
#  1.0,
#  'http://www.wikidata.org/entity/Q154770']
# ['http://data.doremus.org/artist/206a6cfe-2d82-341d-9dbf-01fb63dda672',
#  1.0,
#  'http://www.wikidata.org/entity/Q708863']
# ['http://data.doremus.org/artist/1ff9ca04-4d3b-3733-bbd0-e3b6db2ae68c',
#  1.0,
#  'http://www.wikidata.org/entity/Q4494470']
# ['http://data.doremus.org/artist/2e456353-6634-306a-8a12-b541143e52b8',
#  1.0,
#  'http://www.wikidata.org/entity/Q447945']
# ['http://data.doremus.org/artist/2ee776f4-acff-3653-b662-bddd2e753081',
#  1.0,
#  'http://www.wikidata.org/entity/Q113876']
# ['http://data.doremus.org/artist/3031ea3c-935a-3852-ac6f-7047a0d4933c',
#  1.0,
#  'http://www.wikidata.org/entity/Q742896']
# ['http://data.doremus.org/artist/3046c4e4-d11c-3ca9-8616-34d02e59ea8e',
#  1.0,
#  'http://www.wikidata.org/entity/Q4707761']
# ['http://data.doremus.org/artist/40cfe003-d04b-3d8b-bb1a-f6e1c4417967',
#  1.0,
#  'http://www.wikidata.org/entity/Q448286']
# ['http://data.doremus.org/artist/40be3b76-2ec3-314a-8109-847e0d03d20a',
#  1.0,
#  'http://www.wikidata.org/entity/Q4107873']
# ['http://data.doremus.org/artist/4025d118-169a-3213-abc3-78e93e38066e',
#  1.0,
#  'http://www.wikidata.org/entity/Q275659']
# ['http://data.doremus.org/artist/3ff81c97-097d-3bb7-876d-88b2de3caf44',
#  1.0,
#  'http://www.wikidata.org/entity/Q356499']
# ['http://data.doremus.org/artist/3f7c0c75-ceb1-38bf-aa77-32a9bf29feec',
#  1.0,
#  'http://www.wikidata.org/entity/Q78524']
# ['http://data.doremus.org/artist/3f4e31d9-e14f-3df8-b3ef-e3c10e816a44',
#  1.0,
#  'http://www.wikidata.org/entity/Q964103']
# ['http://data.doremus.org/artist/3eeefefc-f352-32ab-a034-44219aef06d9',
#  1.0,
#  'http://www.wikidata.org/entity/Q380626']
# ['http://data.doremus.org/artist/3de1efe5-e4b3-3f9e-b1b2-3d416f173627',
#  1.0,
#  'http://www.wikidata.org/entity/Q3056474']
# ['http://data.doremus.org/artist/3cc2ee0c-f267-38e5-a50d-231eb6fadb81',
#  1.0,
#  'http://www.wikidata.org/entity/Q2967749']
# ['http://data.doremus.org/artist/3c64e49e-7d33-332b-9ea6-b5595e4953bd',
#  1.0,
#  'http://www.wikidata.org/entity/Q359500']
# ['http://data.doremus.org/artist/1f56799b-76e8-380c-83b8-832dec7a954a',
#  1.0,
#  'http://www.wikidata.org/entity/Q519693']
# ['http://data.doremus.org/artist/3a77735b-37c0-3ed4-b56e-44b1942217b3',
#  1.0,
#  'http://www.wikidata.org/entity/Q573038']
# ['http://data.doremus.org/artist/394b5cd0-7d3a-3074-acf8-ed59798f6e8f',
#  1.0,
#  'http://www.wikidata.org/entity/Q1411581']
# ['http://data.doremus.org/artist/38dffefd-1f7a-3362-8574-9530288b0e06',
#  1.0,
#  'http://www.wikidata.org/entity/Q111074']
# ['http://data.doremus.org/artist/3828eb43-0f08-3a90-9c70-f4c282bbf6ac',
#  1.0,
#  'http://www.wikidata.org/entity/Q210532']
# ['http://data.doremus.org/artist/372b5789-0a98-3959-b6b2-91e3d9c5dd8c',
#  1.0,
#  'http://www.wikidata.org/entity/Q504512']
# ['http://data.doremus.org/artist/36439f06-87d2-33e7-a17f-17cfc69b55c1',
#  1.0,
#  'http://www.wikidata.org/entity/Q606273']
# ['http://data.doremus.org/artist/35f7eaca-a5e0-305f-8f06-e417b6c3d95a',
#  1.0,
#  'http://www.wikidata.org/entity/Q504616']
# ['http://data.doremus.org/artist/35ddad40-c793-312a-86ec-6a1310c030a1',
#  1.0,
#  'http://www.wikidata.org/entity/Q7302']
# ['http://data.doremus.org/artist/33ac3a7a-9fac-3654-81b8-8eb9d99df08c',
#  1.0,
#  'http://www.wikidata.org/entity/Q219491']
# ['http://data.doremus.org/artist/33453884-67c9-3b0f-a8af-7ea8f8c383dd',
#  1.0,
#  'http://www.wikidata.org/entity/Q936002']
# ['http://data.doremus.org/artist/32c2b0ff-35f1-3e65-b0ca-34aaf35f3d50',
#  1.0,
#  'http://www.wikidata.org/entity/Q9726']
# ['http://data.doremus.org/artist/39d0d122-47ce-3edc-a96c-dd349b43cecf',
#  1.0,
#  'http://www.wikidata.org/entity/Q311110']
# ['http://data.doremus.org/artist/1f0e95cb-e8ad-3ca5-965a-f51a29ff526a',
#  1.0,
#  'http://www.wikidata.org/entity/Q3260260']
# ['http://data.doremus.org/artist/1dfd7900-ba90-39d9-ab21-50700e04379f',
#  1.0,
#  'http://www.wikidata.org/entity/Q348282']
# ['http://data.doremus.org/artist/1dc2f6bc-729d-3bb5-82f3-260a6e45aaac',
#  1.0,
#  'http://www.wikidata.org/entity/Q156300']
# ['http://data.doremus.org/artist/0c0348f7-bca2-3655-b2c5-55452568549c',
#  1.0,
#  'http://www.wikidata.org/entity/Q143198']
# ['http://data.doremus.org/artist/0beafa98-acfb-3f24-a915-4bd5b79e376b',
#  1.0,
#  'http://www.wikidata.org/entity/Q338667']
# ['http://data.doremus.org/artist/0bab8dc5-b3b8-368b-aca2-438431386df1',
#  1.0,
#  'http://www.wikidata.org/entity/Q121828']
# ['http://data.doremus.org/artist/0b978496-e9e2-3a3c-b4c6-b267f64bb2c6',
#  1.0,
#  'http://www.wikidata.org/entity/Q294568']
# ['http://data.doremus.org/artist/0b6085f9-4a29-36c9-8078-8fa18b50cc5c',
#  1.0,
#  'http://www.wikidata.org/entity/Q9001525']
# ['http://data.doremus.org/artist/0ab6f234-b219-3564-85e6-6a36d8635b3f',
#  1.0,
#  'http://www.wikidata.org/entity/Q68038']
# ['http://data.doremus.org/artist/09a20ad5-db20-3144-9ce0-32acad2da1a5',
#  1.0,
#  'http://www.wikidata.org/entity/Q543613']
# ['http://data.doremus.org/artist/094023c7-13be-3544-af43-a061650862f0',
#  1.0,
#  'http://www.wikidata.org/entity/Q357326']
# ['http://data.doremus.org/artist/0936cf70-c112-39fc-b018-a2d7508f9c05',
#  1.0,
#  'http://www.wikidata.org/entity/Q33124']
# ['http://data.doremus.org/artist/092a8963-8da8-3ea2-8ab9-ef84d08b624a',
#  1.0,
#  'http://www.wikidata.org/entity/Q67366']
# ['http://data.doremus.org/artist/0d74b492-a80e-3f0f-899b-ec054afe4039',
#  1.0,
#  'http://www.wikidata.org/entity/Q6286224']
# ['http://data.doremus.org/artist/083259cd-1ff0-3e16-81ae-fbf6372da1fc',
#  1.0,
#  'http://www.wikidata.org/entity/Q2173140']
# ['http://data.doremus.org/artist/07a0c2b6-48aa-33b8-a557-0410ae3a7648',
#  1.0,
#  'http://www.wikidata.org/entity/Q273074']
# ['http://data.doremus.org/artist/069e1437-23bf-320f-8581-c22c6077f70e',
#  1.0,
#  'http://www.wikidata.org/entity/Q217068']
# ['http://data.doremus.org/artist/0607b9fe-c6fe-38c1-aa5a-c2cf957bee74',
#  1.0,
#  'http://www.wikidata.org/entity/Q185647']
# ['http://data.doremus.org/artist/05d81772-c5e1-38f2-9571-c9cfd0ad09f9',
#  1.0,
#  'http://www.wikidata.org/entity/Q5932168']
# ['http://data.doremus.org/artist/05a679bb-b069-3edb-86be-c8455418f1ad',
#  1.0,
#  'http://www.wikidata.org/entity/Q77177']
# ['http://data.doremus.org/artist/04a033c0-b92f-3a4f-bd86-a44f8bfa6119',
#  1.0,
#  'http://www.wikidata.org/entity/Q365555']
# ['http://data.doremus.org/artist/03ea5a8c-47ac-3070-9e6c-e107e375e86b',
#  1.0,
#  'http://www.wikidata.org/entity/Q571408']
# ['http://data.doremus.org/artist/03d19961-887e-3811-8b6f-61d9e7493978',
#  1.0,
#  'http://www.wikidata.org/entity/Q2131266']
# ['http://data.doremus.org/artist/026ca0b4-084f-3a1b-8222-b069c4bc16f5',
#  1.0,
#  'http://www.wikidata.org/entity/Q1804']
# ['http://data.doremus.org/artist/00a38a2e-567d-3ad5-a25c-fa46a4e59d18',
#  1.0,
#  'http://www.wikidata.org/entity/Q9554']
# ['http://data.doremus.org/artist/07d63d59-69b0-3d32-9376-911d83f87318',
#  1.0,
#  'http://www.wikidata.org/entity/Q160433']
# ['http://data.doremus.org/artist/40ebbc9d-1cd3-383f-9683-5201184fe040',
#  1.0,
#  'http://www.wikidata.org/entity/Q155467']
# ['http://data.doremus.org/artist/0d8fed3f-d0f5-3861-81a2-e3bf0eff40e3',
#  1.0,
#  'http://www.wikidata.org/entity/Q2062391']
# ['http://data.doremus.org/artist/0fc92ff2-f179-396c-bc96-9be6647d3b4c',
#  1.0,
#  'http://www.wikidata.org/entity/Q3931581']
# ['http://data.doremus.org/artist/1db1862b-b44f-3d32-aa55-ad5c12e19146',
#  1.0,
#  'http://www.wikidata.org/entity/Q1384693']
# ['http://data.doremus.org/artist/1d5a4de8-4ce1-39a4-8da8-4821d47405ed',
#  1.0,
#  'http://www.wikidata.org/entity/Q229613']
# ['http://data.doremus.org/artist/1d38dd94-17bf-3838-bbd5-16ab3f6f4d26',
#  1.0,
#  'http://www.wikidata.org/entity/Q348875']
# ['http://data.doremus.org/artist/1ce421bb-7001-39c7-b96f-1b2d5614a384',
#  1.0,
#  'http://www.wikidata.org/entity/Q96065']
# ['http://data.doremus.org/artist/1c7aea3d-26ed-356c-a264-20ff020c3293',
#  1.0,
#  'http://www.wikidata.org/entity/Q11849978']
# ['http://data.doremus.org/artist/1b6c2060-0844-3992-bece-d8ff46e1482b',
#  1.0,
#  'http://www.wikidata.org/entity/Q214147']
# ['http://data.doremus.org/artist/1ad5dfb7-31bd-397b-be49-e38c5a3652a0',
#  1.0,
#  'http://www.wikidata.org/entity/Q1398016']
# ['http://data.doremus.org/artist/1a3dda47-79eb-3b7a-a510-a684b3ae6398',
#  1.0,
#  'http://www.wikidata.org/entity/Q45095']
# ['http://data.doremus.org/artist/1a3c40ca-15f0-390e-a737-511edcd2f890',
#  1.0,
#  'http://www.wikidata.org/entity/Q503005']
# ['http://data.doremus.org/artist/1a05703a-91fc-3ca6-b3eb-0133507cb368',
#  1.0,
#  'http://www.wikidata.org/entity/Q153776']
# ['http://data.doremus.org/artist/0ddc737a-8413-3b60-a077-1499d75538c9',
#  1.0,
#  'http://www.wikidata.org/entity/Q605191']
# ['http://data.doremus.org/artist/1918a65f-cd9a-3f57-a18e-269cbcefe222',
#  1.0,
#  'http://www.wikidata.org/entity/Q927177']
# ['http://data.doremus.org/artist/14a3fc2e-2b1b-3cc2-abe4-8e7d4aa408a6',
#  1.0,
#  'http://www.wikidata.org/entity/Q200131']
# ['http://data.doremus.org/artist/13928e72-79b6-30e3-a5a7-2e9235af10e7',
#  1.0,
#  'http://www.wikidata.org/entity/Q330024']
# ['http://data.doremus.org/artist/13608860-0375-37cb-9b7d-aa5c26810638',
#  1.0,
#  'http://www.wikidata.org/entity/Q1600793']
# ['http://data.doremus.org/artist/1349acab-2721-379f-8bd3-c08b3df1787b',
#  1.0,
#  'http://www.wikidata.org/entity/Q2161677']
# ['http://data.doremus.org/artist/131fcb8f-ac3a-3cb1-a961-3da27ef9b42b',
#  1.0,
#  'http://www.wikidata.org/entity/Q1264054']
# ['http://data.doremus.org/artist/124efc66-fdd1-3c31-b146-3eff851f58e8',
#  1.0,
#  'http://www.wikidata.org/entity/Q319708']
# ['http://data.doremus.org/artist/122e2721-b72d-3846-be1c-16d06082bb45',
#  1.0,
#  'http://www.wikidata.org/entity/Q103767']
# ['http://data.doremus.org/artist/10eefadb-b40c-353f-a340-422cf725f250',
#  1.0,
#  'http://www.wikidata.org/entity/Q1582156']
# ['http://data.doremus.org/artist/0fe0723a-01ef-3dee-b78c-fb8a6025c42e',
#  1.0,
#  'http://www.wikidata.org/entity/Q7833']
# ['http://data.doremus.org/artist/0fcd95bb-79f8-3c8a-870c-510d428dda1d',
#  1.0,
#  'http://www.wikidata.org/entity/Q5159669']
# ['http://data.doremus.org/artist/181a0220-034a-3c5d-be98-c6e949cd3df6',
#  1.0,
#  'http://www.wikidata.org/entity/Q427214']
# ['http://data.doremus.org/artist/417ed63c-e629-3d72-b9db-56822df08ec4',
#  1.0,
#  'http://www.wikidata.org/entity/Q952902']
# ['http://data.doremus.org/artist/4308c3b5-5c35-343e-85d5-58b887f7e4ff',
#  1.0,
#  'http://www.wikidata.org/entity/Q117110']
# ['http://data.doremus.org/artist/43be2a17-6343-34f1-99fb-92445e153c6b',
#  1.0,
#  'http://www.wikidata.org/entity/Q1972763']
# ['http://data.doremus.org/artist/6a99c949-7cf5-3290-829e-ff2d07b1cf65',
#  1.0,
#  'http://www.wikidata.org/entity/Q152505']
# ['http://data.doremus.org/artist/69dd04e9-74af-3f80-80d7-9cd7b949e1bb',
#  1.0,
#  'http://www.wikidata.org/entity/Q915621']
# ['http://data.doremus.org/artist/69d05ed9-e85f-3182-86b5-a7585d8754a0',
#  1.0,
#  'http://www.wikidata.org/entity/Q1236051']
# ['http://data.doremus.org/artist/68f0530e-1aad-3c4e-9d82-2ad8c4b95ab6',
#  1.0,
#  'http://www.wikidata.org/entity/Q516937']
# ['http://data.doremus.org/artist/6897bd68-a82b-3687-8b6f-62f6c8c748af',
#  1.0,
#  'http://www.wikidata.org/entity/Q205610']
# ['http://data.doremus.org/artist/6881e49d-f073-3727-826e-009c7d668f53',
#  1.0,
#  'http://www.wikidata.org/entity/Q2648593']
# ['http://data.doremus.org/artist/670e2495-8fb2-3517-a5ab-f9170d351174',
#  1.0,
#  'http://www.wikidata.org/entity/Q2524628']
# ['http://data.doremus.org/artist/66ecfb00-69b1-3759-99a8-305e01c283bd',
#  1.0,
#  'http://www.wikidata.org/entity/Q277631']
# ['http://data.doremus.org/artist/66a57943-4937-3adb-8f83-991f5e40417f',
#  1.0,
#  'http://www.wikidata.org/entity/Q1866762']
# ['http://data.doremus.org/artist/6663e562-e738-3bd0-b17d-851ad538a597',
#  1.0,
#  'http://www.wikidata.org/entity/Q1305852']
# ['http://data.doremus.org/artist/6add4a4b-51eb-3bb4-a492-c1ccf6f173ee',
#  1.0,
#  'http://www.wikidata.org/entity/Q1290225']
# ['http://data.doremus.org/artist/6515288f-eff5-31cb-8077-b23213cdb618',
#  1.0,
#  'http://www.wikidata.org/entity/Q181885']
# ['http://data.doremus.org/artist/63560131-92ae-337d-8554-ac029e94e6ed',
#  1.0,
#  'http://www.wikidata.org/entity/Q527400']
# ['http://data.doremus.org/artist/632546cc-44c6-3bf9-88e4-d64956b6a81c',
#  1.0,
#  'http://www.wikidata.org/entity/Q215982']
# ['http://data.doremus.org/artist/628f71e9-029a-3818-93f4-119fa5f6216b',
#  1.0,
#  'http://www.wikidata.org/entity/Q215611']
# ['http://data.doremus.org/artist/61baec7d-68d8-388c-a613-0e95ee070f94',
#  1.0,
#  'http://www.wikidata.org/entity/Q1377646']
# ['http://data.doremus.org/artist/6183e619-f3ff-3b30-9773-ed637a12b894',
#  1.0,
#  'http://www.wikidata.org/entity/Q214665']
# ['http://data.doremus.org/artist/61340e72-7064-3c44-a893-b92f1f5b54ce',
#  1.0,
#  'http://www.wikidata.org/entity/Q185040']
# ['http://data.doremus.org/artist/609d52ea-f3d7-338a-9d3c-c71664de33d2',
#  1.0,
#  'http://www.wikidata.org/entity/Q27037218']
# ['http://data.doremus.org/artist/6096d6c1-9e14-3ca0-bf7e-4fd9e9ea5225',
#  1.0,
#  'http://www.wikidata.org/entity/Q1380497']
# ['http://data.doremus.org/artist/5fd178ee-5291-33ce-973d-e7d06adf25d7',
#  1.0,
#  'http://www.wikidata.org/entity/Q214732']
# ['http://data.doremus.org/artist/5ed05fc7-c745-31bb-a55c-39ec612e5580',
#  1.0,
#  'http://www.wikidata.org/entity/Q215982']
# ['http://data.doremus.org/artist/639a077b-6f4c-3d12-aea3-0ee8cea9172d',
#  1.0,
#  'http://www.wikidata.org/entity/Q158078']
# ['http://data.doremus.org/artist/5e48c90c-b9f7-3be6-b38e-dbbd9d1defb1',
#  1.0,
#  'http://www.wikidata.org/entity/Q80135']
# ['http://data.doremus.org/artist/6b425cfe-a3b0-3fb5-b941-807b4857e2d4',
#  1.0,
#  'http://www.wikidata.org/entity/Q1281741']
# ['http://data.doremus.org/artist/6c3d8dc5-87d7-3532-9dc3-4777723d0fe4',
#  1.0,
#  'http://www.wikidata.org/entity/Q448644']
# ['http://data.doremus.org/artist/7cabe7de-0571-3020-95c7-7330dc564f2a',
#  1.0,
#  'http://www.wikidata.org/entity/Q8067771']
# ['http://data.doremus.org/artist/7b8a925c-713b-377d-8ddf-85dad25d2086',
#  1.0,
#  'http://www.wikidata.org/entity/Q1395288']
# ['http://data.doremus.org/artist/7986e62d-08ad-3fa3-9d0b-ab3653b13170',
#  1.0,
#  'http://www.wikidata.org/entity/Q2006027']
# ['http://data.doremus.org/artist/78f2210e-6e9f-342d-b74d-4e65e1bdfea9',
#  1.0,
#  'http://www.wikidata.org/entity/Q1358755']
# ['http://data.doremus.org/artist/76be25d1-2118-3515-9a9b-4eaad5dbca53',
#  1.0,
#  'http://www.wikidata.org/entity/Q418621']
# ['http://data.doremus.org/artist/76bcff5c-bbd5-3cb8-8a39-c4b45d881668',
#  1.0,
#  'http://www.wikidata.org/entity/Q167242']
# ['http://data.doremus.org/artist/76952b54-73ad-3342-8f16-64c95f25e053',
#  1.0,
#  'http://www.wikidata.org/entity/Q313667']
# ['http://data.doremus.org/artist/7603c20a-1f7e-3dde-8079-d51fd73af5a6',
#  1.0,
#  'http://www.wikidata.org/entity/Q518707']
# ['http://data.doremus.org/artist/75dc16ef-c8ca-32bf-94d9-e8ad09eb04fc',
#  1.0,
#  'http://www.wikidata.org/entity/Q503005']
# ['http://data.doremus.org/artist/73e7b189-7f90-385f-861c-67140deb1ca6',
#  1.0,
#  'http://www.wikidata.org/entity/Q86235']
# ['http://data.doremus.org/artist/6b4e1bc0-8fe6-3674-86a6-89dd808edd36',
#  1.0,
#  'http://www.wikidata.org/entity/Q208546']
# ['http://data.doremus.org/artist/718d00cc-6200-347b-9da2-da8ceca4b3d4',
#  1.0,
#  'http://www.wikidata.org/entity/Q919127']
# ['http://data.doremus.org/artist/707e8584-c173-3bea-85da-cc16fc5e8350',
#  1.0,
#  'http://www.wikidata.org/entity/Q152293']
# ['http://data.doremus.org/artist/6fa0406b-4439-3837-ad6e-67af2c1337c6',
#  1.0,
#  'http://www.wikidata.org/entity/Q5696611']
# ['http://data.doremus.org/artist/6f88aeb7-cfc9-32c6-903d-c5868f2fd9d8',
#  1.0,
#  'http://www.wikidata.org/entity/Q152293']
# ['http://data.doremus.org/artist/6f6890f9-02bc-32de-b134-aedbf39b482a',
#  1.0,
#  'http://www.wikidata.org/entity/Q962316']
# ['http://data.doremus.org/artist/6f5a37d6-b219-3c0c-a933-c0b2b476dd62',
#  1.0,
#  'http://www.wikidata.org/entity/Q694204']
# ['http://data.doremus.org/artist/6f17aa6f-404e-35bd-ab68-d90514f40c75',
#  1.0,
#  'http://www.wikidata.org/entity/Q664913']
# ['http://data.doremus.org/artist/6f084f03-49c1-3a2e-92c4-a958cb9d42ab',
#  1.0,
#  'http://www.wikidata.org/entity/Q45275']
# ['http://data.doremus.org/artist/6d702ffe-8417-3704-876c-2694e0939522',
#  1.0,
#  'http://www.wikidata.org/entity/Q3158642']
# ['http://data.doremus.org/artist/6c733bdd-e8ba-3321-9017-66c00c65cc15',
#  1.0,
#  'http://www.wikidata.org/entity/Q2540023']
# ['http://data.doremus.org/artist/6c3edb69-3aa5-3cf8-8639-ac46a8e5882a',
#  1.0,
#  'http://www.wikidata.org/entity/Q380045']
# ['http://data.doremus.org/artist/708314c9-0721-35e6-90a4-910324bc1dad',
#  1.0,
#  'http://www.wikidata.org/entity/Q919187']
# ['http://data.doremus.org/artist/7d13e3df-a216-3f96-991d-61f1c8230a2d',
#  1.0,
#  'http://www.wikidata.org/entity/Q207951']
# ['http://data.doremus.org/artist/5dc91dc9-3076-361d-847b-06c9ae0c0e88',
#  1.0,
#  'http://www.wikidata.org/entity/Q3419231']
# ['http://data.doremus.org/artist/5c89866a-f2c6-3a93-8d4b-ea9775341d80',
#  1.0,
#  'http://www.wikidata.org/entity/Q1443927']
# ['http://data.doremus.org/artist/5161dd23-ea4a-38da-85a3-d9aa6e6a500d',
#  1.0,
#  'http://www.wikidata.org/entity/Q150471']
# ['http://data.doremus.org/artist/50a03363-2d65-3e47-82b7-f6400be0d8bf',
#  1.0,
#  'http://www.wikidata.org/entity/Q213906']
# ['http://data.doremus.org/artist/4fd85fb7-afb2-3b49-8c19-e0e02f476387',
#  1.0,
#  'http://www.wikidata.org/entity/Q1388452']
# ['http://data.doremus.org/artist/4f0d5849-995f-3b9a-99ca-d597d79ae095',
#  1.0,
#  'http://www.wikidata.org/entity/Q154770']
# ['http://data.doremus.org/artist/4ee595fc-52d0-37ea-b577-455b3fe0e7fa',
#  1.0,
#  'http://www.wikidata.org/entity/Q558405']
# ['http://data.doremus.org/artist/4e21ae31-5390-3843-9236-078f8d4b8c30',
#  1.0,
#  'http://www.wikidata.org/entity/Q1192']
# ['http://data.doremus.org/artist/4dd6889a-ff9d-32b3-8076-5f8c67167e80',
#  1.0,
#  'http://www.wikidata.org/entity/Q213925']
# ['http://data.doremus.org/artist/4cbf4e58-e9e7-324e-9a5f-e4345760d6cd',
#  1.0,
#  'http://www.wikidata.org/entity/Q313980']
# ['http://data.doremus.org/artist/4c784f7d-97a7-3cfa-9aa0-67105eaacec5',
#  1.0,
#  'http://www.wikidata.org/entity/Q680203']
# ['http://data.doremus.org/artist/4c7172c4-2cf7-3ce3-ac97-75f8bf917b2b',
#  1.0,
#  'http://www.wikidata.org/entity/Q235077']
# ['http://data.doremus.org/artist/5238dea0-b58f-3cb3-8517-ce71c58dc9eb',
#  1.0,
#  'http://www.wikidata.org/entity/Q213611']
# ['http://data.doremus.org/artist/4bbc6c1e-6276-38e2-b381-09be7cde2903',
#  1.0,
#  'http://www.wikidata.org/entity/Q213592']
# ['http://data.doremus.org/artist/49c4f96c-813c-3962-b2c2-d066b1ff3ed7',
#  1.0,
#  'http://www.wikidata.org/entity/Q697383']
# ['http://data.doremus.org/artist/499c5737-529f-32a1-9284-7d99b73b1be3',
#  1.0,
#  'http://www.wikidata.org/entity/Q150445']
# ['http://data.doremus.org/artist/497c87fd-f9ac-3e7a-8d4c-66ec3097394a',
#  1.0,
#  'http://www.wikidata.org/entity/Q317128']
# ['http://data.doremus.org/artist/4964b9aa-a451-365b-916d-eb8ecb8efc52',
#  1.0,
#  'http://www.wikidata.org/entity/Q2467902']
# ['http://data.doremus.org/artist/476093b2-f024-3393-8222-aaf235dab73c',
#  1.0,
#  'http://www.wikidata.org/entity/Q555646']
# ['http://data.doremus.org/artist/47306817-7138-3894-8280-c1acf3ddde35',
#  1.0,
#  'http://www.wikidata.org/entity/Q938810']
# ['http://data.doremus.org/artist/46d949ee-ca1c-331e-b88b-f20e0c1c753d',
#  1.0,
#  'http://www.wikidata.org/entity/Q152293']
# ['http://data.doremus.org/artist/448ab394-3511-3da6-b4ea-83213404baa9',
#  1.0,
#  'http://www.wikidata.org/entity/Q3173178']
# ['http://data.doremus.org/artist/43f371a0-f6f8-32a0-90d3-c56f3b0ceda7',
#  1.0,
#  'http://www.wikidata.org/entity/Q325032']
# ['http://data.doremus.org/artist/43cd86d0-1cf1-30d4-ac0b-58ff079fe4d7',
#  1.0,
#  'http://www.wikidata.org/entity/Q318354']
# ['http://data.doremus.org/artist/49fffb96-1a23-358b-9aab-90612224b525',
#  1.0,
#  'http://www.wikidata.org/entity/Q17309163']
# ['http://data.doremus.org/artist/5d64318a-9f08-3830-806c-bc0112ddce4f',
#  1.0,
#  'http://www.wikidata.org/entity/Q1294438']
# ['http://data.doremus.org/artist/527f3763-c29a-35b1-b3fa-884ee5f9acff',
#  1.0,
#  'http://www.wikidata.org/entity/Q377071']
# ['http://data.doremus.org/artist/52bcf6b6-7f9d-308e-ba1e-bbbbfee05d3d',
#  1.0,
#  'http://www.wikidata.org/entity/Q2093106']
# ['http://data.doremus.org/artist/5bca2ee4-be87-3600-a355-35eca60a9955',
#  1.0,
#  'http://www.wikidata.org/entity/Q2041861']
# ['http://data.doremus.org/artist/5bb414bf-cb69-3010-ab78-2fdf619e23c0',
#  1.0,
#  'http://www.wikidata.org/entity/Q7183644']
# ['http://data.doremus.org/artist/5b118a08-6134-3ab6-93bc-b07afad25efa',
#  1.0,
#  'http://www.wikidata.org/entity/Q949849']
# ['http://data.doremus.org/artist/59fc54ec-d5bc-3b3d-920f-68bc2cdd3df1',
#  1.0,
#  'http://www.wikidata.org/entity/Q241252']
# ['http://data.doremus.org/artist/596f1c58-dcaa-3fb7-bf93-d0703018b635',
#  1.0,
#  'http://www.wikidata.org/entity/Q2355124']
# ['http://data.doremus.org/artist/587fe034-c58f-3def-934c-0e0ac572ae06',
#  1.0,
#  'http://www.wikidata.org/entity/Q179631']
# ['http://data.doremus.org/artist/5847af11-6ef8-31e3-ac25-222ae2196ed0',
#  1.0,
#  'http://www.wikidata.org/entity/Q3602423']
# ['http://data.doremus.org/artist/58450f80-40eb-350f-b1fc-7f9665bda79d',
#  1.0,
#  'http://www.wikidata.org/entity/Q6831090']
# ['http://data.doremus.org/artist/583be747-df45-3cda-ac3e-f6a48b4e681a',
#  1.0,
#  'http://www.wikidata.org/entity/Q1389552']
# ['http://data.doremus.org/artist/576cff77-f7c4-3f8a-8ffe-c9cb9cd6cee2',
#  1.0,
#  'http://www.wikidata.org/entity/Q123588']
# ['http://data.doremus.org/artist/52a2a227-bb28-396b-a163-226e91629b53',
#  1.0,
#  'http://www.wikidata.org/entity/Q2587302']
# ['http://data.doremus.org/artist/572c26db-f1c3-334b-857c-5673e0850722',
#  1.0,
#  'http://www.wikidata.org/entity/Q3604384']
# ['http://data.doremus.org/artist/56536f37-e298-3fb9-ade4-3aa79af9e2b4',
#  1.0,
#  'http://www.wikidata.org/entity/Q303']
# ['http://data.doremus.org/artist/560edfda-843b-3ac6-bf49-de9d65993ac9',
#  1.0,
#  'http://www.wikidata.org/entity/Q297562']
# ['http://data.doremus.org/artist/55d2a933-ee7c-36aa-a5c5-02e6c22182cd',
#  1.0,
#  'http://www.wikidata.org/entity/Q130759']
# ['http://data.doremus.org/artist/5497fdc6-b58a-3410-a87b-bde8f4da3e75',
#  1.0,
#  'http://www.wikidata.org/entity/Q365985']
# ['http://data.doremus.org/artist/5475ea38-f521-3094-9b66-1a4559fbce19',
#  1.0,
#  'http://www.wikidata.org/entity/Q360840']
# ['http://data.doremus.org/artist/53931247-4905-3c6f-bcd5-0ae0891e95a1',
#  1.0,
#  'http://www.wikidata.org/entity/Q2977736']
# ['http://data.doremus.org/artist/53777d20-0cb0-360f-b7f1-a59e412992f3',
#  1.0,
#  'http://www.wikidata.org/entity/Q1684913']
# ['http://data.doremus.org/artist/5367d17c-4ac7-3499-9659-2faaeaf13cb6',
#  1.0,
#  'http://www.wikidata.org/entity/Q587741']
# ['http://data.doremus.org/artist/52f2dd3b-4a99-3234-930d-1c548e8918c5',
#  1.0,
#  'http://www.wikidata.org/entity/Q977702']
# ['http://data.doremus.org/artist/52ed6199-6a11-316d-9933-8a0b862f1f65',
#  1.0,
#  'http://www.wikidata.org/entity/Q1355782']
# ['http://data.doremus.org/artist/566029dd-9da5-3bf9-93be-5080c07efade',
#  1.0,
#  'http://www.wikidata.org/entity/Q57275']
# ['http://data.doremus.org/artist/fe82b187-f440-3cb1-b9ce-65c95d1788eb',
#  1.0,
#  'http://www.wikidata.org/entity/Q1178302']
